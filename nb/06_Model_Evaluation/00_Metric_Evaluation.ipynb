# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # Init

# %%
import json
import sys
import re
import pickle as pkl
from pathlib import Path
from functools import partial
from collections import defaultdict, namedtuple
sys.path.append("../src")

import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
from joblib import Parallel, delayed
from tqdm import tqdm
from sklearn.metrics import classification_report, precision_recall_fscore_support, accuracy_score, confusion_matrix

import constants
from scoring import scorer
from gen.util import read_data, write_jsonl
from rte import aggregate

# %%
data_sent_micro_p = Path("/users/k21190024/study/fact-check-transfer-learning/scratch/dumps/bert-data-sent-evidence")

pred_p = Path("/users/k21190024/study/fact-check-transfer-learning/scratch/thesis/predictions")
result_p = Path("/users/k21190024/study/fact-check-transfer-learning/scratch/thesis/results/metrics")

fever_actual_p = Path("/users/k21190024/study/fact-check-transfer-learning/scratch/dumps/fever-nei-sampled")
cfever_actual_p = Path("/users/k21190024/study/fact-check-transfer-learning/scratch/dumps/climatefever-neg-sampled")
cfeverpure_actual_p = Path("/users/k21190024/study/fact-check-transfer-learning/scratch/dumps/climatefeverpure-neg-sampled")
sf_actual_p = Path("/users/k21190024/study/fact-check-transfer-learning/scratch/dumps/scifact-nei-sampled")

actual_pls = (
    list(fever_actual_p.glob("*.n5.nei.jsonl")) 
    + list(cfever_actual_p.glob("*.n5.nei.jsonl")) 
    + list(cfeverpure_actual_p.glob("*.n5.nei.jsonl")) 
    + list(sf_actual_p.glob("*.n5.nei.jsonl"))
)
actual_pls = [p for p in actual_pls if "train" not in p.stem]

# %% [markdown]
# # Concatenate Evidences

# %%
concat_evi_res = {
    "fever": defaultdict(list), 
    "climatefeverpure": defaultdict(list), 
    "climatefever": defaultdict(list),
    "scifact": defaultdict(list),
    "scifactpipeline": defaultdict(list),
}

for actual_dp in tqdm(actual_pls):
    dataset = actual_dp.parent.stem.split("-")[0]
    split = actual_dp.stem.split(".")[0]
    actual_data = read_data(actual_dp)
    if dataset == "climatefeverpure":
        score_obj = scorer.ClimateFEVERScorer
    elif dataset == "climatefever":
        score_obj = scorer.ClimateFEVERScorer
    else:
        score_obj = scorer.FEVERScorer
        
    for pp in pred_p.joinpath("doc", dataset).glob(f"*.{split}.jsonl"):
        preds = read_data(pp)
        concat_evi_res[dataset][split].append(score_obj(
            actual_data=actual_data, 
            prediction_data=preds, 
            score_name=pp.stem, 
            oracle_rte=False, 
            oracle_ir=True, 
            max_evidence=99999
        ))
    if dataset == "scifact":
        dataset = "scifactpipeline"
        for pp in pred_p.joinpath("doc", dataset).glob(f"*.{split}.jsonl"):
            preds = read_data(pp)
            concat_evi_res[dataset][split].append(score_obj(
                actual_data=actual_data, 
                prediction_data=preds, 
                score_name=pp.stem, 
                oracle_rte=False, 
                oracle_ir=False, 
                max_evidence=99999
            ))
# Out:
# 100%|██████████| 9/9 [00:29<00:00,  3.32s/it]

# %%
with result_p.joinpath("concatenate_evidences_metrics.pkl").open("wb") as fn:
    pkl.dump(concat_evi_res, fn)

# %%
for score in concat_evi_res["fever"]["dev"]:
    print(score._score_name)
    print(score.classification_report)
    print("===")
# Out:
# fever-climatefeverpure-bert-base-uncased.dev
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.9994    0.9961    0.9977      3333
#         REFUTES     0.9643    0.9163    0.9397      3333
#        SUPPORTS     0.9194    0.9682    0.9432      3333
#
#        accuracy                         0.9602      9999
#       macro avg     0.9610    0.9602    0.9602      9999
#    weighted avg     0.9610    0.9602    0.9602      9999
#
# ===
# fever-da.dev
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.9368    0.9421    0.9394      3333
#         REFUTES     0.8523    0.5299    0.6535      3333
#        SUPPORTS     0.6501    0.8923    0.7521      3333
#
#        accuracy                         0.7881      9999
#       macro avg     0.8130    0.7881    0.7817      9999
#    weighted avg     0.8130    0.7881    0.7817      9999
#
# ===
# climatefeverpure-xlnet-base-cased.dev
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.8520    0.9394    0.8936      3333
#         REFUTES     0.8945    0.3537    0.5070      3333
#        SUPPORTS     0.5999    0.9010    0.7202      3333
#
#        accuracy                         0.7314      9999
#       macro avg     0.7821    0.7314    0.7069      9999
#    weighted avg     0.7821    0.7314    0.7069      9999
#
# ===
# fever-xlnet-base-cased.dev
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.9994    0.9967    0.9980      3333
#         REFUTES     0.9628    0.9253    0.9437      3333
#        SUPPORTS     0.9274    0.9661    0.9464      3333
#
#        accuracy                         0.9627      9999
#       macro avg     0.9632    0.9627    0.9627      9999
#    weighted avg     0.9632    0.9627    0.9627      9999
#
# ===
# fever-climatefeverpure-da.dev
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.9675    0.9907    0.9790      3333
#         REFUTES     0.8702    0.7684    0.8161      3333
#        SUPPORTS     0.8004    0.8749    0.8360      3333
#
#        accuracy                         0.8780      9999
#       macro avg     0.8794    0.8780    0.8770      9999
#    weighted avg     0.8794    0.8780    0.8770      9999
#
# ===
# climatefeverpure-bert-base-uncased.dev
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.8512    0.9625    0.9034      3333
#         REFUTES     0.9338    0.0888    0.1622      3333
#        SUPPORTS     0.5216    0.9253    0.6671      3333
#
#        accuracy                         0.6589      9999
#       macro avg     0.7688    0.6589    0.5776      9999
#    weighted avg     0.7688    0.6589    0.5776      9999
#
# ===
# fever-climatefeverpure-xlnet-base-cased.dev
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.9988    0.9958    0.9973      3333
#         REFUTES     0.9645    0.9142    0.9387      3333
#        SUPPORTS     0.9187    0.9694    0.9434      3333
#
#        accuracy                         0.9598      9999
#       macro avg     0.9607    0.9598    0.9598      9999
#    weighted avg     0.9607    0.9598    0.9598      9999
#
# ===
# fever-bert-base-uncased.dev
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.9976    0.9946    0.9961      3333
#         REFUTES     0.9586    0.9238    0.9409      3333
#        SUPPORTS     0.9258    0.9622    0.9437      3333
#
#        accuracy                         0.9602      9999
#       macro avg     0.9607    0.9602    0.9602      9999
#    weighted avg     0.9607    0.9602    0.9602      9999
#
# ===
# climatefeverpure-da.dev
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.6571    0.5578    0.6034      3333
#         REFUTES     0.3637    0.3756    0.3696      3333
#        SUPPORTS     0.4370    0.4887    0.4614      3333
#
#        accuracy                         0.4740      9999
#       macro avg     0.4859    0.4740    0.4781      9999
#    weighted avg     0.4859    0.4740    0.4781      9999
#
# ===

# %%
for score in concat_evi_res["climatefeverpure"]["dev"]:
    print(score._score_name)
    print(score.classification_report)
    print("===")
# Out:
# fever-climatefeverpure-bert-base-uncased.dev
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.8767    0.6737    0.7619        95
#         REFUTES     0.4638    0.6275    0.5333        51
#        SUPPORTS     0.7500    0.7727    0.7612       132
#
#        accuracy                         0.7122       278
#       macro avg     0.6968    0.6913    0.6855       278
#    weighted avg     0.7408    0.7122    0.7196       278
#
# ===
# fever-da.dev
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.4171    0.9263    0.5752        95
#         REFUTES     0.2593    0.1373    0.1795        51
#        SUPPORTS     0.6750    0.2045    0.3140       132
#
#        accuracy                         0.4388       278
#       macro avg     0.4504    0.4227    0.3562       278
#    weighted avg     0.5106    0.4388    0.3785       278
#
# ===
# climatefeverpure-xlnet-base-cased.dev
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.8750    0.8842    0.8796        95
#         REFUTES     0.6531    0.6275    0.6400        51
#        SUPPORTS     0.8045    0.8106    0.8075       132
#
#        accuracy                         0.8022       278
#       macro avg     0.7775    0.7741    0.7757       278
#    weighted avg     0.8008    0.8022    0.8014       278
#
# ===
# fever-xlnet-base-cased.dev
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.7833    0.4947    0.6065        95
#         REFUTES     0.4167    0.6863    0.5185        51
#        SUPPORTS     0.7090    0.7197    0.7143       132
#
#        accuracy                         0.6367       278
#       macro avg     0.6363    0.6336    0.6131       278
#    weighted avg     0.6808    0.6367    0.6415       278
#
# ===
# fever-climatefeverpure-da.dev
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.6829    0.8842    0.7706        95
#         REFUTES     0.5625    0.3529    0.4337        51
#        SUPPORTS     0.7724    0.7197    0.7451       132
#
#        accuracy                         0.7086       278
#       macro avg     0.6726    0.6523    0.6498       278
#    weighted avg     0.7033    0.7086    0.6967       278
#
# ===
# climatefeverpure-bert-base-uncased.dev
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.8632    0.8632    0.8632        95
#         REFUTES     0.5526    0.4118    0.4719        51
#        SUPPORTS     0.7517    0.8258    0.7870       132
#
#        accuracy                         0.7626       278
#       macro avg     0.7225    0.7002    0.7074       278
#    weighted avg     0.7533    0.7626    0.7552       278
#
# ===
# fever-climatefeverpure-xlnet-base-cased.dev
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.8696    0.8421    0.8556        95
#         REFUTES     0.6875    0.6471    0.6667        51
#        SUPPORTS     0.8116    0.8485    0.8296       132
#
#        accuracy                         0.8094       278
#       macro avg     0.7896    0.7792    0.7840       278
#    weighted avg     0.8086    0.8094    0.8086       278
#
# ===
# fever-bert-base-uncased.dev
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.9310    0.2842    0.4355        95
#         REFUTES     0.3040    0.7451    0.4318        51
#        SUPPORTS     0.7177    0.6742    0.6953       132
#
#        accuracy                         0.5540       278
#       macro avg     0.6509    0.5679    0.5209       278
#    weighted avg     0.7147    0.5540    0.5582       278
#
# ===
# climatefeverpure-da.dev
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.7500    0.8211    0.7839        95
#         REFUTES     0.5714    0.2353    0.3333        51
#        SUPPORTS     0.6732    0.7803    0.7228       132
#
#        accuracy                         0.6942       278
#       macro avg     0.6649    0.6122    0.6134       278
#    weighted avg     0.6808    0.6942    0.6722       278
#
# ===

# %%
for score in concat_evi_res["climatefever"]["dev"]:
    print(score._score_name)
    print(score.classification_report)
    print("===")
# Out:
# fever-climatefeverpure-bert-base-uncased.dev
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.4414    0.6737    0.5333        95
#         REFUTES     0.4651    0.3922    0.4255        51
#        SUPPORTS     0.7444    0.5076    0.6036       132
#
#        accuracy                         0.5432       278
#       macro avg     0.5503    0.5245    0.5208       278
#    weighted avg     0.5896    0.5432    0.5469       278
#
# ===
# fever-da.dev
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.3385    0.9263    0.4958        95
#         REFUTES     0.3333    0.0196    0.0370        51
#        SUPPORTS     0.5333    0.0606    0.1088       132
#
#        accuracy                         0.3489       278
#       macro avg     0.4017    0.3355    0.2139       278
#    weighted avg     0.4300    0.3489    0.2279       278
#
# ===
# climatefeverpure-xlnet-base-cased.dev
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.4264    0.8842    0.5753        95
#         REFUTES     0.9231    0.2353    0.3750        51
#        SUPPORTS     0.7794    0.4015    0.5300       132
#
#        accuracy                         0.5360       278
#       macro avg     0.7096    0.5070    0.4934       278
#    weighted avg     0.6851    0.5360    0.5171       278
#
# ===
# fever-xlnet-base-cased.dev
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.5281    0.4947    0.5109        95
#         REFUTES     0.4133    0.6078    0.4921        51
#        SUPPORTS     0.6667    0.5758    0.6179       132
#
#        accuracy                         0.5540       278
#       macro avg     0.5360    0.5594    0.5403       278
#    weighted avg     0.5728    0.5540    0.5582       278
#
# ===
# fever-climatefeverpure-da.dev
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.3871    0.8842    0.5385        95
#         REFUTES     0.5833    0.1373    0.2222        51
#        SUPPORTS     0.7347    0.2727    0.3978       132
#
#        accuracy                         0.4568       278
#       macro avg     0.5684    0.4314    0.3862       278
#    weighted avg     0.5881    0.4568    0.4137       278
#
# ===
# climatefeverpure-bert-base-uncased.dev
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.4409    0.8632    0.5836        95
#         REFUTES     0.6250    0.1961    0.2985        51
#        SUPPORTS     0.7368    0.4242    0.5385       132
#
#        accuracy                         0.5324       278
#       macro avg     0.6009    0.4945    0.4735       278
#    weighted avg     0.6152    0.5324    0.5099       278
#
# ===
# fever-climatefeverpure-xlnet-base-cased.dev
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.4678    0.8421    0.6015        95
#         REFUTES     0.6667    0.3137    0.4267        51
#        SUPPORTS     0.7831    0.4924    0.6047       132
#
#        accuracy                         0.5791       278
#       macro avg     0.6392    0.5494    0.5443       278
#    weighted avg     0.6540    0.5791    0.5709       278
#
# ===
# fever-bert-base-uncased.dev
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.5400    0.2842    0.3724        95
#         REFUTES     0.2937    0.7255    0.4181        51
#        SUPPORTS     0.6961    0.5379    0.6068       132
#
#        accuracy                         0.4856       278
#       macro avg     0.5099    0.5159    0.4658       278
#    weighted avg     0.5689    0.4856    0.4921       278
#
# ===
# climatefeverpure-da.dev
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.4062    0.8211    0.5436        95
#         REFUTES     0.7273    0.1569    0.2581        51
#        SUPPORTS     0.6133    0.3485    0.4444       132
#
#        accuracy                         0.4748       278
#       macro avg     0.5823    0.4421    0.4154       278
#    weighted avg     0.5635    0.4748    0.4441       278
#
# ===

# %%
for score in concat_evi_res["scifact"]["all"]:
    print(score._score_name)
    print(score.classification_report)
    print("===")
# Out:
# climatefeverpure-bert-base-uncased.all
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.8782    0.9880    0.9299       416
#         REFUTES     0.6053    0.0970    0.1673       237
#        SUPPORTS     0.6733    0.8904    0.7668       456
#
#        accuracy                         0.7574      1109
#       macro avg     0.7189    0.6585    0.6213      1109
#    weighted avg     0.7356    0.7574    0.6998      1109
#
# ===
# fever-climatefeverpure-da.all
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.7030    0.3413    0.4595       416
#         REFUTES     0.2935    0.2278    0.2565       237
#        SUPPORTS     0.4938    0.7829    0.6056       456
#
#        accuracy                         0.4986      1109
#       macro avg     0.4967    0.4507    0.4406      1109
#    weighted avg     0.5294    0.4986    0.4762      1109
#
# ===
# fever-bert-base-uncased.all
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.8832    1.0000    0.9380       416
#         REFUTES     0.5990    0.4979    0.5438       237
#        SUPPORTS     0.7891    0.7632    0.7759       456
#
#        accuracy                         0.7953      1109
#       macro avg     0.7571    0.7537    0.7526      1109
#    weighted avg     0.7838    0.7953    0.7871      1109
#
# ===
# climatefeverpure-da.all
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.7354    0.7548    0.7450       416
#         REFUTES     0.3333    0.1519    0.2087       237
#        SUPPORTS     0.5819    0.7325    0.6485       456
#
#        accuracy                         0.6168      1109
#       macro avg     0.5502    0.5464    0.5341      1109
#    weighted avg     0.5863    0.6168    0.5907      1109
#
# ===
# fever-climatefeverpure-bert-base-uncased.all
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.9306    1.0000    0.9641       416
#         REFUTES     0.6887    0.4388    0.5361       237
#        SUPPORTS     0.7691    0.8618    0.8128       456
#
#        accuracy                         0.8233      1109
#       macro avg     0.7962    0.7669    0.7710      1109
#    weighted avg     0.8125    0.8233    0.8104      1109
#
# ===
# fever-da.all
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.4519    0.9832    0.6192       416
#         REFUTES     0.4600    0.0970    0.1603       237
#        SUPPORTS     0.7078    0.2390    0.3574       456
#
#        accuracy                         0.4878      1109
#       macro avg     0.5399    0.4398    0.3790      1109
#    weighted avg     0.5589    0.4878    0.4135      1109
#
# ===
# fever-xlnet-base-cased.all
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.8849    0.9976    0.9379       416
#         REFUTES     0.6759    0.4135    0.5131       237
#        SUPPORTS     0.7717    0.8377    0.8034       456
#
#        accuracy                         0.8070      1109
#       macro avg     0.7775    0.7496    0.7514      1109
#    weighted avg     0.7937    0.8070    0.7918      1109
#
# ===
# fever-climatefeverpure-xlnet-base-cased.all
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.8889    1.0000    0.9412       416
#         REFUTES     0.6899    0.4599    0.5519       237
#        SUPPORTS     0.7888    0.8355    0.8115       456
#
#        accuracy                         0.8170      1109
#       macro avg     0.7892    0.7651    0.7682      1109
#    weighted avg     0.8052    0.8170    0.8047      1109
#
# ===
# climatefeverpure-xlnet-base-cased.all
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.8971    0.9639    0.9293       416
#         REFUTES     0.6364    0.3840    0.4789       237
#        SUPPORTS     0.7399    0.8421    0.7877       456
#
#        accuracy                         0.7899      1109
#       macro avg     0.7578    0.7300    0.7320      1109
#    weighted avg     0.7767    0.7899    0.7748      1109
#
# ===

# %%
for score in concat_evi_res["scifact"]["dev"]:
    print(score._score_name)
    print(score.classification_report)
    print("===")
# Out:
# fever-climatefeverpure-bert-base-uncased.dev
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.9333    1.0000    0.9655       112
#         REFUTES     0.7805    0.5000    0.6095        64
#        SUPPORTS     0.7914    0.8871    0.8365       124
#
#        accuracy                         0.8467       300
#       macro avg     0.8351    0.7957    0.8038       300
#    weighted avg     0.8420    0.8467    0.8362       300
#
# ===
# fever-da.dev
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.4592    0.9554    0.6203       112
#         REFUTES     0.5882    0.1562    0.2469        64
#        SUPPORTS     0.7600    0.3065    0.4368       124
#
#        accuracy                         0.5167       300
#       macro avg     0.6025    0.4727    0.4347       300
#    weighted avg     0.6111    0.5167    0.4648       300
#
# ===
# climatefeverpure-xlnet-base-cased.dev
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.9091    0.9821    0.9442       112
#         REFUTES     0.5952    0.3906    0.4717        64
#        SUPPORTS     0.7226    0.7984    0.7586       124
#
#        accuracy                         0.7800       300
#       macro avg     0.7423    0.7237    0.7248       300
#    weighted avg     0.7651    0.7800    0.7667       300
#
# ===
# fever-xlnet-base-cased.dev
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.9106    1.0000    0.9532       112
#         REFUTES     0.7297    0.4219    0.5347        64
#        SUPPORTS     0.7786    0.8790    0.8258       124
#
#        accuracy                         0.8267       300
#       macro avg     0.8063    0.7670    0.7712       300
#    weighted avg     0.8174    0.8267    0.8112       300
#
# ===
# fever-climatefeverpure-da.dev
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.6852    0.3304    0.4458       112
#         REFUTES     0.3115    0.2969    0.3040        64
#        SUPPORTS     0.5135    0.7661    0.6149       124
#
#        accuracy                         0.5033       300
#       macro avg     0.5034    0.4645    0.4549       300
#    weighted avg     0.5345    0.5033    0.4854       300
#
# ===
# climatefeverpure-bert-base-uncased.dev
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.8952    0.9911    0.9407       112
#         REFUTES     0.5000    0.0938    0.1579        64
#        SUPPORTS     0.6646    0.8790    0.7569       124
#
#        accuracy                         0.7533       300
#       macro avg     0.6866    0.6546    0.6185       300
#    weighted avg     0.7156    0.7533    0.6977       300
#
# ===
# fever-climatefeverpure-xlnet-base-cased.dev
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.9032    1.0000    0.9492       112
#         REFUTES     0.7568    0.4375    0.5545        64
#        SUPPORTS     0.7698    0.8629    0.8137       124
#
#        accuracy                         0.8233       300
#       macro avg     0.8099    0.7668    0.7724       300
#    weighted avg     0.8168    0.8233    0.8090       300
#
# ===
# fever-bert-base-uncased.dev
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.9333    1.0000    0.9655       112
#         REFUTES     0.7000    0.5469    0.6140        64
#        SUPPORTS     0.8077    0.8468    0.8268       124
#
#        accuracy                         0.8400       300
#       macro avg     0.8137    0.7979    0.8021       300
#    weighted avg     0.8316    0.8400    0.8332       300
#
# ===
# climatefeverpure-da.dev
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.7545    0.7411    0.7477       112
#         REFUTES     0.2500    0.0938    0.1364        64
#        SUPPORTS     0.5783    0.7742    0.6621       124
#
#        accuracy                         0.6167       300
#       macro avg     0.5276    0.5363    0.5154       300
#    weighted avg     0.5741    0.6167    0.5819       300
#
# ===

# %%
for score in concat_evi_res["scifactpipeline"]["all"]:
    print(score._score_name)
    print(score.classification_report)
    print("===")
# Out:
# climatefeverpure-bert-base-uncased.all
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.5051    0.5986    0.5479       416
#         REFUTES     0.5833    0.0295    0.0562       237
#        SUPPORTS     0.5116    0.6776    0.5830       456
#
#        accuracy                         0.5095      1109
#       macro avg     0.5333    0.4352    0.3957      1109
#    weighted avg     0.5245    0.5095    0.4572      1109
#
# ===
# fever-climatefeverpure-da.all
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.3716    0.1322    0.1950       416
#         REFUTES     0.2966    0.1477    0.1972       237
#        SUPPORTS     0.4484    0.8289    0.5820       456
#
#        accuracy                         0.4220      1109
#       macro avg     0.3722    0.3696    0.3247      1109
#    weighted avg     0.3872    0.4220    0.3546      1109
#
# ===
# fever-bert-base-uncased.all
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.6093    0.2212    0.3245       416
#         REFUTES     0.3475    0.4135    0.3776       237
#        SUPPORTS     0.5325    0.7895    0.6360       456
#
#        accuracy                         0.4959      1109
#       macro avg     0.4964    0.4747    0.4461      1109
#    weighted avg     0.5218    0.4959    0.4640      1109
#
# ===
# climatefeverpure-da.all
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.3723    0.8269    0.5134       416
#         REFUTES     0.2162    0.0675    0.1029       237
#        SUPPORTS     0.4054    0.0987    0.1587       456
#
#        accuracy                         0.3652      1109
#       macro avg     0.3313    0.3310    0.2584      1109
#    weighted avg     0.3526    0.3652    0.2799      1109
#
# ===
# fever-climatefeverpure-bert-base-uncased.all
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.6158    0.3005    0.4039       416
#         REFUTES     0.4396    0.3840    0.4099       237
#        SUPPORTS     0.5279    0.8092    0.6390       456
#
#        accuracy                         0.5275      1109
#       macro avg     0.5278    0.4979    0.4842      1109
#    weighted avg     0.5420    0.5275    0.5018      1109
#
# ===
# fever-da.all
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.3752    0.9832    0.5432       416
#         REFUTES     0.3333    0.0042    0.0083       237
#        SUPPORTS     0.4375    0.0154    0.0297       456
#
#        accuracy                         0.3760      1109
#       macro avg     0.3820    0.3342    0.1937      1109
#    weighted avg     0.3919    0.3760    0.2177      1109
#
# ===
# fever-xlnet-base-cased.all
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.6174    0.4615    0.5282       416
#         REFUTES     0.4709    0.3418    0.3961       237
#        SUPPORTS     0.5655    0.7763    0.6543       456
#
#        accuracy                         0.5654      1109
#       macro avg     0.5513    0.5265    0.5262      1109
#    weighted avg     0.5647    0.5654    0.5518      1109
#
# ===
# fever-climatefeverpure-xlnet-base-cased.all
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.5800    0.6707    0.6221       416
#         REFUTES     0.5288    0.2321    0.3226       237
#        SUPPORTS     0.6011    0.6908    0.6429       456
#
#        accuracy                         0.5852      1109
#       macro avg     0.5700    0.5312    0.5292      1109
#    weighted avg     0.5778    0.5852    0.5666      1109
#
# ===
# climatefeverpure-xlnet-base-cased.all
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.4487    0.7572    0.5635       416
#         REFUTES     0.5556    0.0211    0.0407       237
#        SUPPORTS     0.5980    0.5219    0.5574       456
#
#        accuracy                         0.5032      1109
#       macro avg     0.5341    0.4334    0.3872      1109
#    weighted avg     0.5329    0.5032    0.4492      1109
#
# ===

# %%
for score in concat_evi_res["scifactpipeline"]["dev"]:
    print(score._score_name)
    print(score.classification_report)
    print("===")
# Out:
# fever-climatefeverpure-bert-base-uncased.dev
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.5273    0.2589    0.3473       112
#         REFUTES     0.3770    0.3594    0.3680        64
#        SUPPORTS     0.5380    0.7984    0.6429       124
#
#        accuracy                         0.5033       300
#       macro avg     0.4808    0.4722    0.4527       300
#    weighted avg     0.4997    0.5033    0.4739       300
#
# ===
# fever-da.dev
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.3715    0.9554    0.5350       112
#         REFUTES     0.3333    0.0156    0.0299        64
#        SUPPORTS     0.5556    0.0403    0.0752       124
#
#        accuracy                         0.3767       300
#       macro avg     0.4201    0.3371    0.2133       300
#    weighted avg     0.4394    0.3767    0.2372       300
#
# ===
# climatefeverpure-xlnet-base-cased.dev
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.4293    0.7321    0.5413       112
#         REFUTES     0.2500    0.0156    0.0294        64
#        SUPPORTS     0.5619    0.4758    0.5153       124
#
#        accuracy                         0.4733       300
#       macro avg     0.4137    0.4079    0.3620       300
#    weighted avg     0.4459    0.4733    0.4213       300
#
# ===
# fever-xlnet-base-cased.dev
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.6517    0.5179    0.5771       112
#         REFUTES     0.4773    0.3281    0.3889        64
#        SUPPORTS     0.5808    0.7823    0.6667       124
#
#        accuracy                         0.5867       300
#       macro avg     0.5699    0.5427    0.5442       300
#    weighted avg     0.5852    0.5867    0.5740       300
#
# ===
# fever-climatefeverpure-da.dev
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.3415    0.1250    0.1830       112
#         REFUTES     0.2812    0.1406    0.1875        64
#        SUPPORTS     0.4493    0.8226    0.5812       124
#
#        accuracy                         0.4167       300
#       macro avg     0.3574    0.3627    0.3172       300
#    weighted avg     0.3732    0.4167    0.3486       300
#
# ===
# climatefeverpure-bert-base-uncased.dev
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.4895    0.6250    0.5490       112
#         REFUTES     1.0000    0.0469    0.0896        64
#        SUPPORTS     0.5065    0.6290    0.5612       124
#
#        accuracy                         0.5033       300
#       macro avg     0.6653    0.4336    0.3999       300
#    weighted avg     0.6054    0.5033    0.4560       300
#
# ===
# fever-climatefeverpure-xlnet-base-cased.dev
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.6077    0.7054    0.6529       112
#         REFUTES     0.5000    0.2031    0.2889        64
#        SUPPORTS     0.5903    0.6855    0.6343       124
#
#        accuracy                         0.5900       300
#       macro avg     0.5660    0.5313    0.5254       300
#    weighted avg     0.5775    0.5900    0.5676       300
#
# ===
# fever-bert-base-uncased.dev
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.6000    0.2143    0.3158       112
#         REFUTES     0.2987    0.3594    0.3262        64
#        SUPPORTS     0.5464    0.8065    0.6515       124
#
#        accuracy                         0.4900       300
#       macro avg     0.4817    0.4600    0.4312       300
#    weighted avg     0.5136    0.4900    0.4568       300
#
# ===
# climatefeverpure-da.dev
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.3682    0.8482    0.5135       112
#         REFUTES     0.2353    0.0625    0.0988        64
#        SUPPORTS     0.3600    0.0726    0.1208       124
#
#        accuracy                         0.3600       300
#       macro avg     0.3212    0.3278    0.2444       300
#    weighted avg     0.3365    0.3600    0.2627       300
#
# ===

# %% [markdown]
# # Sentence

# %%
sent_pls = list(data_sent_micro_p.glob("*.dev*")) + list(data_sent_micro_p.glob("*.test*"))
sent_pls = [p for p in sent_pls if "fever-climatefever" not in p.stem and "scifact_test" not in p.stem]

# %% [markdown]
# ## Micro verdict

# %%
sent_micro_res = {
    "fever": defaultdict(list), 
    "climatefeverpure": defaultdict(list), 
    "scifact": defaultdict(list),
    "climatefever": defaultdict(list),
    "scifactpipeline": defaultdict(list),
    "scifactneiignore": defaultdict(list)
}

for actual_dp in tqdm(sent_pls):
    dataset = actual_dp.stem.split(".")[0]
    split = actual_dp.stem.split(".")[1]
    actual_data = read_data(actual_dp)
    if dataset == "scifactpipeline":
        labelled_data = pd.DataFrame(read_data(Path("/users/k21190024/study/fact-check-transfer-learning/scratch/dumps/feverised-scifact/scifact_all.jsonl")))
        labelled_data["claim_id"] = labelled_data["id"].map(lambda x: f"scifact|{x}")
        labelled_data["labels"] = labelled_data["label"].map(constants.LABEL2ID)
        actual_data = pd.DataFrame(actual_data).drop(columns="labels")
        actual_data = actual_data.merge(labelled_data[["claim_id", "labels"]], on="claim_id", how="left")
        actual_data = actual_data.to_dict("records")
        del labelled_data
    elif dataset == "scifact_test":
        continue
    
    for pp in pred_p.joinpath("sent", dataset).glob(f"*.{split}.jsonl"):
        preds = read_data(pp)
        
        assert len(actual_data) == len(preds), f"{actual_dp} ({len(actual_data)}) != {pp} ({len(preds)})"
        
        actual_labels = [constants.ID2LABEL[i["labels"]] for i in actual_data]
        predicted_labels = [i["predicted_label"] for i in preds]

        ma_p, ma_r, ma_f, _ = precision_recall_fscore_support(y_true=actual_labels, y_pred=predicted_labels, average="macro", beta=1.0)
        mi_p, mi_r, mi_f, _ = precision_recall_fscore_support(y_true=actual_labels, y_pred=predicted_labels, average="micro", beta=1.0)
        rte_metrics = {
            "accuracy": accuracy_score(y_true=actual_labels, y_pred=predicted_labels),
            "macro_precision": ma_p,
            "macro_recall": ma_r,
            "macro_f1": ma_f,
            "micro_precision": mi_p,
            "micro_recall": mi_r,
            "micro_f1": mi_f
        }
        
        sent_micro_res[dataset][split].append(scorer.SentenceMicroScorer(
            pp.stem, 
            classification_report(y_true=actual_labels, y_pred=predicted_labels, digits=4),
            classification_report(y_true=actual_labels, y_pred=predicted_labels, output_dict=True),
            rte_metrics,
            confusion_matrix(y_true=actual_labels, y_pred=predicted_labels, labels=["SUPPORTS", "NOT ENOUGH INFO", "REFUTES"])
        ))
        
        if dataset == "scifact":
            predicted_neitrue_labels = [actual if actual == constants.LOOKUP["label"]["nei"] else pred for actual, pred in zip(actual_labels, predicted_labels)]
            ma_p, ma_r, ma_f, _ = precision_recall_fscore_support(y_true=actual_labels, y_pred=predicted_neitrue_labels, average="macro", beta=1.0)
            mi_p, mi_r, mi_f, _ = precision_recall_fscore_support(y_true=actual_labels, y_pred=predicted_neitrue_labels, average="micro", beta=1.0)
            rte_metrics = {
                "accuracy": accuracy_score(y_true=actual_labels, y_pred=predicted_neitrue_labels),
                "macro_precision": ma_p,
                "macro_recall": ma_r,
                "macro_f1": ma_f,
                "micro_precision": mi_p,
                "micro_recall": mi_r,
                "micro_f1": mi_f
            }

            sent_micro_res["scifactneiignore"][split].append(scorer.SentenceMicroScorer(
                pp.stem, 
                classification_report(y_true=actual_labels, y_pred=predicted_neitrue_labels, digits=4),
                classification_report(y_true=actual_labels, y_pred=predicted_neitrue_labels, output_dict=True),
                rte_metrics,
                confusion_matrix(y_true=actual_labels, y_pred=predicted_labels, labels=["SUPPORTS", "NOT ENOUGH INFO", "REFUTES"])
            ))
# Out:
# 100%|██████████| 10/10 [00:29<00:00,  2.97s/it]

# %%
with result_p.joinpath("sent_micro_verdict_metrics.pkl").open("wb") as fn:
    pkl.dump(sent_micro_res, fn)

# %%
for score in sent_micro_res["fever"]["dev"]:
    print(score._score_name)
    print(score.classification_report)
    print("===")
# Out:
# fever-climatefeverpure-bert-base-uncased.dev
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.9716    0.9916    0.9815      6666
#         REFUTES     0.9651    0.9180    0.9410      6235
#        SUPPORTS     0.9402    0.9655    0.9527      6207
#
#        accuracy                         0.9591     19108
#       macro avg     0.9590    0.9584    0.9584     19108
#    weighted avg     0.9593    0.9591    0.9589     19108
#
# ===
# fever-climatefever-bert-base-uncased.dev
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.9669    0.9896    0.9781      6666
#         REFUTES     0.9605    0.9174    0.9385      6235
#        SUPPORTS     0.9422    0.9609    0.9514      6207
#
#        accuracy                         0.9567     19108
#       macro avg     0.9565    0.9560    0.9560     19108
#    weighted avg     0.9568    0.9567    0.9565     19108
#
# ===
# climatefeverpure-xlnet-base-cased.dev
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.5279    0.9070    0.6673      6666
#         REFUTES     0.9147    0.1307    0.2287      6235
#        SUPPORTS     0.5926    0.6457    0.6180      6207
#
#        accuracy                         0.5688     19108
#       macro avg     0.6784    0.5611    0.5047     19108
#    weighted avg     0.6751    0.5688    0.5082     19108
#
# ===
# fever-xlnet-base-cased.dev
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.9849    0.9779    0.9814      6666
#         REFUTES     0.9542    0.9387    0.9464      6235
#        SUPPORTS     0.9443    0.9668    0.9554      6207
#
#        accuracy                         0.9615     19108
#       macro avg     0.9611    0.9612    0.9611     19108
#    weighted avg     0.9617    0.9615    0.9615     19108
#
# ===
# climatefever-xlnet-base-cased.dev
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.4239    0.9931    0.5942      6666
#         REFUTES     0.9610    0.1147    0.2049      6235
#        SUPPORTS     0.7376    0.3266    0.4527      6207
#
#        accuracy                         0.4900     19108
#       macro avg     0.7075    0.4781    0.4173     19108
#    weighted avg     0.7011    0.4900    0.4212     19108
#
# ===
# climatefeverpure-bert-base-uncased.dev
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.6030    0.9086    0.7250      6666
#         REFUTES     0.9345    0.1944    0.3218      6235
#        SUPPORTS     0.5962    0.7461    0.6628      6207
#
#        accuracy                         0.6228     19108
#       macro avg     0.7113    0.6164    0.5699     19108
#    weighted avg     0.7090    0.6228    0.5732     19108
#
# ===
# fever-climatefeverpure-xlnet-base-cased.dev
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.9846    0.9787    0.9816      6666
#         REFUTES     0.9540    0.9378    0.9458      6235
#        SUPPORTS     0.9440    0.9662    0.9549      6207
#
#        accuracy                         0.9613     19108
#       macro avg     0.9609    0.9609    0.9608     19108
#    weighted avg     0.9614    0.9613    0.9613     19108
#
# ===
# fever-bert-base-uncased.dev
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.9728    0.9910    0.9818      6666
#         REFUTES     0.9632    0.9200    0.9411      6235
#        SUPPORTS     0.9423    0.9658    0.9539      6207
#
#        accuracy                         0.9597     19108
#       macro avg     0.9594    0.9589    0.9589     19108
#    weighted avg     0.9598    0.9597    0.9595     19108
#
# ===
# climatefever-bert-base-uncased.dev
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.5308    0.9877    0.6905      6666
#         REFUTES     0.9408    0.1095    0.1962      6235
#        SUPPORTS     0.6724    0.6477    0.6598      6207
#
#        accuracy                         0.5907     19108
#       macro avg     0.7147    0.5816    0.5155     19108
#    weighted avg     0.7106    0.5907    0.5193     19108
#
# ===
# fever-climatefever-xlnet-base-cased.dev
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.9840    0.9794    0.9817      6666
#         REFUTES     0.9550    0.9387    0.9468      6235
#        SUPPORTS     0.9444    0.9652    0.9547      6207
#
#        accuracy                         0.9615     19108
#       macro avg     0.9611    0.9611    0.9611     19108
#    weighted avg     0.9617    0.9615    0.9615     19108
#
# ===

# %%
for score in sent_micro_res["climatefeverpure"]["dev"]:
    print(score._score_name)
    print(score.classification_report)
    print("===")
# Out:
# fever-climatefeverpure-bert-base-uncased.dev
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.6762    0.7432    0.7081       475
#         REFUTES     0.4357    0.4621    0.4485       132
#        SUPPORTS     0.6906    0.5719    0.6256       320
#
#        accuracy                         0.6440       927
#       macro avg     0.6008    0.5924    0.5941       927
#    weighted avg     0.6469    0.6440    0.6427       927
#
# ===
# fever-climatefever-bert-base-uncased.dev
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.5924    0.9516    0.7302       475
#         REFUTES     0.6341    0.1970    0.3006       132
#        SUPPORTS     0.8374    0.3219    0.4650       320
#
#        accuracy                         0.6268       927
#       macro avg     0.6880    0.4901    0.4986       927
#    weighted avg     0.6829    0.6268    0.5775       927
#
# ===
# climatefeverpure-xlnet-base-cased.dev
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.7541    0.6779    0.7140       475
#         REFUTES     0.7000    0.5303    0.6034       132
#        SUPPORTS     0.5900    0.7375    0.6556       320
#
#        accuracy                         0.6775       927
#       macro avg     0.6814    0.6486    0.6577       927
#    weighted avg     0.6897    0.6775    0.6781       927
#
# ===
# fever-xlnet-base-cased.dev
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.6967    0.3095    0.4286       475
#         REFUTES     0.2931    0.6439    0.4028       132
#        SUPPORTS     0.5023    0.6687    0.5737       320
#
#        accuracy                         0.4811       927
#       macro avg     0.4974    0.5407    0.4684       927
#    weighted avg     0.5721    0.4811    0.4750       927
#
# ===
# climatefever-xlnet-base-cased.dev
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.6351    0.8463    0.7256       475
#         REFUTES     0.8246    0.3561    0.4974       132
#        SUPPORTS     0.6624    0.4906    0.5637       320
#
#        accuracy                         0.6537       927
#       macro avg     0.7074    0.5643    0.5956       927
#    weighted avg     0.6715    0.6537    0.6372       927
#
# ===
# climatefeverpure-bert-base-uncased.dev
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.7633    0.6042    0.6745       475
#         REFUTES     0.5172    0.4545    0.4839       132
#        SUPPORTS     0.5770    0.7844    0.6649       320
#
#        accuracy                         0.6451       927
#       macro avg     0.6192    0.6144    0.6078       927
#    weighted avg     0.6640    0.6451    0.6440       927
#
# ===
# fever-climatefeverpure-xlnet-base-cased.dev
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.7506    0.6084    0.6721       475
#         REFUTES     0.6056    0.6515    0.6277       132
#        SUPPORTS     0.5975    0.7469    0.6639       320
#
#        accuracy                         0.6624       927
#       macro avg     0.6513    0.6689    0.6546       927
#    weighted avg     0.6771    0.6624    0.6629       927
#
# ===
# fever-bert-base-uncased.dev
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.8000    0.2358    0.3642       475
#         REFUTES     0.2312    0.6970    0.3472       132
#        SUPPORTS     0.5553    0.6750    0.6093       320
#
#        accuracy                         0.4531       927
#       macro avg     0.5288    0.5359    0.4402       927
#    weighted avg     0.6345    0.4531    0.4464       927
#
# ===
# climatefever-bert-base-uncased.dev
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.6472    0.9347    0.7649       475
#         REFUTES     0.7895    0.3409    0.4762       132
#        SUPPORTS     0.7772    0.4469    0.5675       320
#
#        accuracy                         0.6818       927
#       macro avg     0.7380    0.5742    0.6028       927
#    weighted avg     0.7123    0.6818    0.6556       927
#
# ===
# fever-climatefever-xlnet-base-cased.dev
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.6753    0.8800    0.7642       475
#         REFUTES     0.7250    0.4394    0.5472       132
#        SUPPORTS     0.7588    0.5406    0.6314       320
#
#        accuracy                         0.7001       927
#       macro avg     0.7197    0.6200    0.6476       927
#    weighted avg     0.7112    0.7001    0.6874       927
#
# ===

# %%
for score in sent_micro_res["climatefever"]["dev"]:
    print(score._score_name)
    print(score.classification_report)
    print("===")
# Out:
# fever-climatefeverpure-bert-base-uncased.dev
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.7874    0.6674    0.7224       938
#         REFUTES     0.3280    0.4621    0.3836       132
#        SUPPORTS     0.4474    0.5719    0.5021       320
#
#        accuracy                         0.6259      1390
#       macro avg     0.5209    0.5671    0.5361      1390
#    weighted avg     0.6655    0.6259    0.6395      1390
#
# ===
# fever-climatefever-bert-base-uncased.dev
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.7344    0.9168    0.8156       938
#         REFUTES     0.4727    0.1970    0.2781       132
#        SUPPORTS     0.6280    0.3219    0.4256       320
#
#        accuracy                         0.7115      1390
#       macro avg     0.6117    0.4786    0.5064      1390
#    weighted avg     0.6851    0.7115    0.6747      1390
#
# ===
# climatefeverpure-xlnet-base-cased.dev
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.8273    0.5362    0.6507       938
#         REFUTES     0.4094    0.5303    0.4620       132
#        SUPPORTS     0.3863    0.7375    0.5070       320
#
#        accuracy                         0.5820      1390
#       macro avg     0.5410    0.6014    0.5399      1390
#    weighted avg     0.6861    0.5820    0.5997      1390
#
# ===
# fever-xlnet-base-cased.dev
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.7908    0.2580    0.3891       938
#         REFUTES     0.1945    0.6439    0.2988       132
#        SUPPORTS     0.3308    0.6687    0.4426       320
#
#        accuracy                         0.3892      1390
#       macro avg     0.4387    0.5236    0.3768      1390
#    weighted avg     0.6283    0.3892    0.3928      1390
#
# ===
# climatefever-xlnet-base-cased.dev
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.7548    0.7580    0.7564       938
#         REFUTES     0.6267    0.3561    0.4541       132
#        SUPPORTS     0.4209    0.4906    0.4531       320
#
#        accuracy                         0.6583      1390
#       macro avg     0.6008    0.5349    0.5545      1390
#    weighted avg     0.6658    0.6583    0.6579      1390
#
# ===
# climatefeverpure-bert-base-uncased.dev
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.8311    0.4670    0.5980       938
#         REFUTES     0.3509    0.4545    0.3960       132
#        SUPPORTS     0.3627    0.7844    0.4960       320
#
#        accuracy                         0.5388      1390
#       macro avg     0.5149    0.5686    0.4967      1390
#    weighted avg     0.6777    0.5388    0.5553      1390
#
# ===
# fever-climatefeverpure-xlnet-base-cased.dev
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.8328    0.5096    0.6323       938
#         REFUTES     0.4216    0.6515    0.5119       132
#        SUPPORTS     0.3905    0.7469    0.5129       320
#
#        accuracy                         0.5777      1390
#       macro avg     0.5483    0.6360    0.5524      1390
#    weighted avg     0.6919    0.5777    0.5934      1390
#
# ===
# fever-bert-base-uncased.dev
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.8647    0.1908    0.3127       938
#         REFUTES     0.1551    0.6970    0.2538       132
#        SUPPORTS     0.3661    0.6750    0.4747       320
#
#        accuracy                         0.3504      1390
#       macro avg     0.4620    0.5209    0.3471      1390
#    weighted avg     0.6826    0.3504    0.3444      1390
#
# ===
# climatefever-bert-base-uncased.dev
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.7682    0.8550    0.8093       938
#         REFUTES     0.6000    0.3409    0.4348       132
#        SUPPORTS     0.5277    0.4469    0.4839       320
#
#        accuracy                         0.7122      1390
#       macro avg     0.6320    0.5476    0.5760      1390
#    weighted avg     0.6969    0.7122    0.6988      1390
#
# ===
# fever-climatefever-xlnet-base-cased.dev
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.7904    0.8081    0.7992       938
#         REFUTES     0.5370    0.4394    0.4833       132
#        SUPPORTS     0.5356    0.5406    0.5381       320
#
#        accuracy                         0.7115      1390
#       macro avg     0.6210    0.5960    0.6069      1390
#    weighted avg     0.7077    0.7115    0.7091      1390
#
# ===

# %%
for score in sent_micro_res["scifact"]["all"]:
    print(score._score_name)
    print(score.classification_report)
    print("===")
# Out:
# fever-climatefever-xlnet-base-cased.all
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.5108    0.4555    0.4816       832
#         REFUTES     0.4519    0.3952    0.4217       463
#        SUPPORTS     0.5490    0.6466    0.5938       832
#
#        accuracy                         0.5172      2127
#       macro avg     0.5039    0.4991    0.4990      2127
#    weighted avg     0.5129    0.5172    0.5124      2127
#
# ===
# climatefeverpure-bert-base-uncased.all
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.6579    0.1502    0.2446       832
#         REFUTES     0.4049    0.1793    0.2485       463
#        SUPPORTS     0.4273    0.8894    0.5772       832
#
#        accuracy                         0.4457      2127
#       macro avg     0.4967    0.4063    0.3568      2127
#    weighted avg     0.5126    0.4457    0.3756      2127
#
# ===
# climatefever-xlnet-base-cased.all
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.4574    0.5745    0.5093       832
#         REFUTES     0.5345    0.0670    0.1190       463
#        SUPPORTS     0.4990    0.6142    0.5506       832
#
#        accuracy                         0.4795      2127
#       macro avg     0.4970    0.4186    0.3930      2127
#    weighted avg     0.4905    0.4795    0.4405      2127
#
# ===
# fever-bert-base-uncased.all
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.2000    0.0481    0.0775       832
#         REFUTES     0.3497    0.5680    0.4329       463
#        SUPPORTS     0.5081    0.7175    0.5949       832
#
#        accuracy                         0.4231      2127
#       macro avg     0.3526    0.4446    0.3685      2127
#    weighted avg     0.3531    0.4231    0.3573      2127
#
# ===
# fever-climatefeverpure-bert-base-uncased.all
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.4171    0.2873    0.3402       832
#         REFUTES     0.3869    0.4212    0.4033       463
#        SUPPORTS     0.5114    0.6454    0.5707       832
#
#        accuracy                         0.4565      2127
#       macro avg     0.4385    0.4513    0.4381      2127
#    weighted avg     0.4474    0.4565    0.4441      2127
#
# ===
# fever-climatefever-bert-base-uncased.all
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.4501    0.4663    0.4581       832
#         REFUTES     0.4270    0.2527    0.3175       463
#        SUPPORTS     0.5197    0.6190    0.5650       832
#
#        accuracy                         0.4795      2127
#       macro avg     0.4656    0.4460    0.4469      2127
#    weighted avg     0.4723    0.4795    0.4693      2127
#
# ===
# climatefever-bert-base-uncased.all
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.5104    0.4411    0.4732       832
#         REFUTES     0.4370    0.1123    0.1787       463
#        SUPPORTS     0.4787    0.7416    0.5818       832
#
#        accuracy                         0.4871      2127
#       macro avg     0.4754    0.4317    0.4112      2127
#    weighted avg     0.4820    0.4871    0.4516      2127
#
# ===
# fever-xlnet-base-cased.all
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.3211    0.0950    0.1466       832
#         REFUTES     0.4098    0.4708    0.4382       463
#        SUPPORTS     0.4863    0.7885    0.6016       832
#
#        accuracy                         0.4480      2127
#       macro avg     0.4057    0.4514    0.3954      2127
#    weighted avg     0.4050    0.4480    0.3880      2127
#
# ===
# fever-climatefeverpure-xlnet-base-cased.all
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.4530    0.2488    0.3212       832
#         REFUTES     0.4677    0.4060    0.4347       463
#        SUPPORTS     0.4897    0.7464    0.5914       832
#
#        accuracy                         0.4777      2127
#       macro avg     0.4701    0.4671    0.4491      2127
#    weighted avg     0.4705    0.4777    0.4516      2127
#
# ===
# climatefeverpure-xlnet-base-cased.all
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.5034    0.3522    0.4144       832
#         REFUTES     0.5464    0.2289    0.3227       463
#        SUPPORTS     0.4611    0.7488    0.5708       832
#
#        accuracy                         0.4805      2127
#       macro avg     0.5037    0.4433    0.4360      2127
#    weighted avg     0.4962    0.4805    0.4556      2127
#
# ===

# %%
for score in sent_micro_res["scifact"]["dev"]:
    print(score._score_name)
    print(score.classification_report)
    print("===")
# Out:
# fever-climatefeverpure-bert-base-uncased.dev
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.4156    0.2857    0.3386       224
#         REFUTES     0.3459    0.3770    0.3608       122
#        SUPPORTS     0.5018    0.6389    0.5621       216
#
#        accuracy                         0.4413       562
#       macro avg     0.4211    0.4339    0.4205       562
#    weighted avg     0.4336    0.4413    0.4293       562
#
# ===
# fever-climatefever-bert-base-uncased.dev
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.4542    0.4866    0.4698       224
#         REFUTES     0.3871    0.1967    0.2609       122
#        SUPPORTS     0.5154    0.6204    0.5630       216
#
#        accuracy                         0.4751       562
#       macro avg     0.4522    0.4346    0.4312       562
#    weighted avg     0.4631    0.4751    0.4603       562
#
# ===
# climatefeverpure-xlnet-base-cased.dev
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.5395    0.3661    0.4362       224
#         REFUTES     0.4167    0.2049    0.2747       122
#        SUPPORTS     0.4343    0.7037    0.5371       216
#
#        accuracy                         0.4609       562
#       macro avg     0.4635    0.4249    0.4160       562
#    weighted avg     0.4724    0.4609    0.4399       562
#
# ===
# fever-xlnet-base-cased.dev
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.3538    0.1027    0.1592       224
#         REFUTES     0.3857    0.4426    0.4122       122
#        SUPPORTS     0.4762    0.7870    0.5934       216
#
#        accuracy                         0.4395       562
#       macro avg     0.4053    0.4441    0.3883       562
#    weighted avg     0.4078    0.4395    0.3810       562
#
# ===
# climatefever-xlnet-base-cased.dev
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.4947    0.6205    0.5505       224
#         REFUTES     0.3158    0.0492    0.0851       122
#        SUPPORTS     0.4962    0.6019    0.5439       216
#
#        accuracy                         0.4893       562
#       macro avg     0.4355    0.4239    0.3932       562
#    weighted avg     0.4564    0.4893    0.4469       562
#
# ===
# climatefeverpure-bert-base-uncased.dev
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.6727    0.1652    0.2652       224
#         REFUTES     0.2766    0.1066    0.1538       122
#        SUPPORTS     0.4174    0.8889    0.5680       216
#
#        accuracy                         0.4306       562
#       macro avg     0.4556    0.3869    0.3290       562
#    weighted avg     0.4886    0.4306    0.3574       562
#
# ===
# fever-climatefeverpure-xlnet-base-cased.dev
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.5000    0.2634    0.3450       224
#         REFUTES     0.4953    0.4344    0.4629       122
#        SUPPORTS     0.4777    0.7454    0.5823       216
#
#        accuracy                         0.4858       562
#       macro avg     0.4910    0.4811    0.4634       562
#    weighted avg     0.4904    0.4858    0.4618       562
#
# ===
# fever-bert-base-uncased.dev
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.2642    0.0625    0.1011       224
#         REFUTES     0.3268    0.5492    0.4098       122
#        SUPPORTS     0.5033    0.7083    0.5885       216
#
#        accuracy                         0.4164       562
#       macro avg     0.3648    0.4400    0.3664       562
#    weighted avg     0.3697    0.4164    0.3554       562
#
# ===
# climatefever-bert-base-uncased.dev
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.4901    0.4420    0.4648       224
#         REFUTES     0.2059    0.0574    0.0897       122
#        SUPPORTS     0.4663    0.7037    0.5609       216
#
#        accuracy                         0.4591       562
#       macro avg     0.3874    0.4010    0.3718       562
#    weighted avg     0.4192    0.4591    0.4203       562
#
# ===
# fever-climatefever-xlnet-base-cased.dev
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.5312    0.4554    0.4904       224
#         REFUTES     0.4951    0.4180    0.4533       122
#        SUPPORTS     0.5318    0.6574    0.5880       216
#
#        accuracy                         0.5249       562
#       macro avg     0.5194    0.5103    0.5106       562
#    weighted avg     0.5236    0.5249    0.5199       562
#
# ===

# %%
for score in sent_micro_res["scifactpipeline"]["all"]:
    print(score._score_name)
    print(score.classification_report)
    print("===")
# Out:
# fever-climatefever-xlnet-base-cased.all
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.5273    0.5476    0.5373      2080
#         REFUTES     0.4130    0.3544    0.3815      1185
#        SUPPORTS     0.5604    0.5820    0.5710      2280
#
#        accuracy                         0.5205      5545
#       macro avg     0.5002    0.4947    0.4966      5545
#    weighted avg     0.5165    0.5205    0.5178      5545
#
# ===
# climatefeverpure-bert-base-uncased.all
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.6208    0.1606    0.2552      2080
#         REFUTES     0.3279    0.1350    0.1913      1185
#        SUPPORTS     0.4448    0.8816    0.5913      2280
#
#        accuracy                         0.4516      5545
#       macro avg     0.4645    0.3924    0.3459      5545
#    weighted avg     0.4858    0.4516    0.3797      5545
#
# ===
# climatefever-xlnet-base-cased.all
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.4626    0.6308    0.5338      2080
#         REFUTES     0.4362    0.0549    0.0975      1185
#        SUPPORTS     0.5234    0.5877    0.5537      2280
#
#        accuracy                         0.4900      5545
#       macro avg     0.4741    0.4244    0.3950      5545
#    weighted avg     0.4820    0.4900    0.4487      5545
#
# ===
# fever-bert-base-uncased.all
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.7830    0.0798    0.1449      2080
#         REFUTES     0.3227    0.6059    0.4211      1185
#        SUPPORTS     0.5199    0.7088    0.5999      2280
#
#        accuracy                         0.4509      5545
#       macro avg     0.5419    0.4648    0.3886      5545
#    weighted avg     0.5765    0.4509    0.3910      5545
#
# ===
# fever-climatefeverpure-bert-base-uncased.all
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.5302    0.3760    0.4399      2080
#         REFUTES     0.3680    0.4481    0.4041      1185
#        SUPPORTS     0.5413    0.6237    0.5796      2280
#
#        accuracy                         0.4932      5545
#       macro avg     0.4798    0.4826    0.4745      5545
#    weighted avg     0.5001    0.4932    0.4897      5545
#
# ===
# fever-climatefever-bert-base-uncased.all
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.4886    0.5481    0.5167      2080
#         REFUTES     0.3972    0.2414    0.3003      1185
#        SUPPORTS     0.5534    0.6048    0.5780      2280
#
#        accuracy                         0.5059      5545
#       macro avg     0.4797    0.4648    0.4650      5545
#    weighted avg     0.4957    0.5059    0.4956      5545
#
# ===
# climatefever-bert-base-uncased.all
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.5172    0.4913    0.5039      2080
#         REFUTES     0.3866    0.0878    0.1431      1185
#        SUPPORTS     0.5033    0.7285    0.5953      2280
#
#        accuracy                         0.5026      5545
#       macro avg     0.4691    0.4359    0.4141      5545
#    weighted avg     0.4836    0.5026    0.4644      5545
#
# ===
# fever-xlnet-base-cased.all
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.6513    0.1490    0.2426      2080
#         REFUTES     0.3499    0.4515    0.3943      1185
#        SUPPORTS     0.4969    0.7715    0.6045      2280
#
#        accuracy                         0.4696      5545
#       macro avg     0.4994    0.4573    0.4138      5545
#    weighted avg     0.5234    0.4696    0.4238      5545
#
# ===
# fever-climatefeverpure-xlnet-base-cased.all
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.5850    0.3327    0.4241      2080
#         REFUTES     0.4130    0.3705    0.3906      1185
#        SUPPORTS     0.5065    0.7329    0.5990      2280
#
#        accuracy                         0.5053      5545
#       macro avg     0.5015    0.4787    0.4713      5545
#    weighted avg     0.5160    0.5053    0.4889      5545
#
# ===
# climatefeverpure-xlnet-base-cased.all
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.5238    0.3966    0.4514      2080
#         REFUTES     0.4492    0.1679    0.2445      1185
#        SUPPORTS     0.4817    0.7452    0.5852      2280
#
#        accuracy                         0.4911      5545
#       macro avg     0.4849    0.4366    0.4270      5545
#    weighted avg     0.4906    0.4911    0.4622      5545
#
# ===

# %%
for score in sent_micro_res["scifactpipeline"]["dev"]:
    print(score._score_name)
    print(score.classification_report)
    print("===")
# Out:
# fever-climatefeverpure-bert-base-uncased.dev
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.5177    0.3661    0.4289       560
#         REFUTES     0.3400    0.4281    0.3790       320
#        SUPPORTS     0.5521    0.6242    0.5859       620
#
#        accuracy                         0.4860      1500
#       macro avg     0.4699    0.4728    0.4646      1500
#    weighted avg     0.4940    0.4860    0.4831      1500
#
# ===
# fever-climatefever-bert-base-uncased.dev
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.4725    0.5679    0.5158       560
#         REFUTES     0.3506    0.1906    0.2470       320
#        SUPPORTS     0.5574    0.5871    0.5719       620
#
#        accuracy                         0.4953      1500
#       macro avg     0.4602    0.4485    0.4449      1500
#    weighted avg     0.4816    0.4953    0.4816      1500
#
# ===
# climatefeverpure-xlnet-base-cased.dev
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.5142    0.3893    0.4431       560
#         REFUTES     0.3023    0.1219    0.1737       320
#        SUPPORTS     0.4773    0.7290    0.5769       620
#
#        accuracy                         0.4727      1500
#       macro avg     0.4313    0.4134    0.3979      1500
#    weighted avg     0.4537    0.4727    0.4409      1500
#
# ===
# fever-xlnet-base-cased.dev
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.6309    0.1679    0.2652       560
#         REFUTES     0.3461    0.4250    0.3815       320
#        SUPPORTS     0.5084    0.7855    0.6172       620
#
#        accuracy                         0.4780      1500
#       macro avg     0.4951    0.4594    0.4213      1500
#    weighted avg     0.5195    0.4780    0.4355      1500
#
# ===
# climatefever-xlnet-base-cased.dev
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.4724    0.6411    0.5439       560
#         REFUTES     0.3396    0.0563    0.0965       320
#        SUPPORTS     0.5313    0.5887    0.5585       620
#
#        accuracy                         0.4947      1500
#       macro avg     0.4478    0.4287    0.3997      1500
#    weighted avg     0.4684    0.4947    0.4545      1500
#
# ===
# climatefeverpure-bert-base-uncased.dev
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.6065    0.1679    0.2629       560
#         REFUTES     0.2481    0.1031    0.1457       320
#        SUPPORTS     0.4332    0.8468    0.5731       620
#
#        accuracy                         0.4347      1500
#       macro avg     0.4292    0.3726    0.3273      1500
#    weighted avg     0.4584    0.4347    0.3661      1500
#
# ===
# fever-climatefeverpure-xlnet-base-cased.dev
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.5655    0.3161    0.4055       560
#         REFUTES     0.4228    0.3594    0.3885       320
#        SUPPORTS     0.5104    0.7532    0.6085       620
#
#        accuracy                         0.5060      1500
#       macro avg     0.4996    0.4762    0.4675      1500
#    weighted avg     0.5123    0.5060    0.4858      1500
#
# ===
# fever-bert-base-uncased.dev
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.8116    0.1000    0.1781       560
#         REFUTES     0.2952    0.5719    0.3894       320
#        SUPPORTS     0.5203    0.6806    0.5898       620
#
#        accuracy                         0.4407      1500
#       macro avg     0.5424    0.4508    0.3857      1500
#    weighted avg     0.5810    0.4407    0.3933      1500
#
# ===
# climatefever-bert-base-uncased.dev
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.4792    0.4732    0.4762       560
#         REFUTES     0.2530    0.0656    0.1042       320
#        SUPPORTS     0.4954    0.6903    0.5768       620
#
#        accuracy                         0.4760      1500
#       macro avg     0.4092    0.4097    0.3857      1500
#    weighted avg     0.4376    0.4760    0.4384      1500
#
# ===
# fever-climatefever-xlnet-base-cased.dev
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.5042    0.5321    0.5178       560
#         REFUTES     0.4111    0.3250    0.3630       320
#        SUPPORTS     0.5671    0.6000    0.5831       620
#
#        accuracy                         0.5160      1500
#       macro avg     0.4941    0.4857    0.4880      1500
#    weighted avg     0.5103    0.5160    0.5118      1500
#
# ===

# %% [markdown]
# ## Macro verdict

# %% [markdown]
# ### Majority

# %%
majority_agg_res = {
    "fever": defaultdict(list), 
    "climatefeverpure": defaultdict(list), 
    "scifact": defaultdict(list),
    "climatefever": defaultdict(list),
    "scifactpipeline": defaultdict(list)
}

for actual_dp in tqdm(actual_pls):
    dataset = actual_dp.parent.stem.split("-")[0]
    split = actual_dp.stem.split(".")[0]
    actual_data = read_data(actual_dp)
    if "climatefever" in dataset:
        score_obj = scorer.ClimateFEVERScorer
    else:
        score_obj = scorer.FEVERScorer
        
    for pp in pred_p.joinpath("sent", dataset).glob(f"*.{split}.jsonl"):
        preds = read_data(pp)
        
        # aggregate
        preds = pd.DataFrame(preds)
        preds["predicted_label"] = preds["predicted_label"].map(constants.LABEL2ID)
        preds = preds.groupby("claim_id", sort=False, as_index=False).agg({"predicted_label": aggregate.agg_predict})
        preds["predicted_label"] = preds["predicted_label"].map(constants.ID2LABEL)
        preds = preds.to_dict("records")
        
        assert all([int(a["id"]) == int(p["claim_id"].split("|")[1]) for a, p in zip(actual_data, preds)])
        
        majority_agg_res[dataset][split].append(score_obj(
            actual_data=actual_data, 
            prediction_data=preds, 
            oracle_rte=False, 
            oracle_ir=True, 
            max_evidence=99999, 
            score_name=pp.stem
        ))
    if dataset == "scifact":
        dataset = "scifactpipeline"
        for pp in pred_p.joinpath("sent", dataset).glob(f"*.{split}.jsonl"):
            preds = read_data(pp)

            # aggregate
            preds = pd.DataFrame(preds)
            preds["predicted_label"] = preds["predicted_label"].map(constants.LABEL2ID)
            preds = preds.groupby("claim_id", sort=False, as_index=False).agg({
                "predicted_label": aggregate.agg_predict,
                "predicted_evidence": lambda ls: [i for i in ls]
            })
            preds["predicted_label"] = preds["predicted_label"].map(constants.ID2LABEL)
            preds = preds.to_dict("records")
            
            assert all([int(a["id"]) == int(p["claim_id"].split("|")[1]) for a, p in zip(actual_data, preds)])

            majority_agg_res[dataset][split].append(score_obj(
                actual_data=actual_data, 
                prediction_data=preds, 
                oracle_rte=False, 
                oracle_ir=False, 
                max_evidence=99999, 
                score_name=pp.stem
            ))
# Out:
# 100%|██████████| 9/9 [00:33<00:00,  3.68s/it]

# %%
with result_p.joinpath("sent_macro_verdict_majority_metrics.pkl").open("wb") as fn:
    pkl.dump(majority_agg_res, fn)

# %%
for score in majority_agg_res["fever"]["dev"]:
    print(score._score_name)
    print(score.classification_report)
    print("===")
# Out:
# fever-climatefeverpure-bert-base-uncased.dev
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.9883    0.9859    0.9871      3333
#         REFUTES     0.9591    0.9157    0.9369      3333
#        SUPPORTS     0.9198    0.9637    0.9412      3333
#
#        accuracy                         0.9551      9999
#       macro avg     0.9557    0.9551    0.9551      9999
#    weighted avg     0.9557    0.9551    0.9551      9999
#
# ===
# fever-climatefever-bert-base-uncased.dev
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.9873    0.9823    0.9848      3333
#         REFUTES     0.9546    0.9148    0.9343      3333
#        SUPPORTS     0.9200    0.9631    0.9411      3333
#
#        accuracy                         0.9534      9999
#       macro avg     0.9540    0.9534    0.9534      9999
#    weighted avg     0.9540    0.9534    0.9534      9999
#
# ===
# climatefeverpure-xlnet-base-cased.dev
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.5622    0.8719    0.6836      3333
#         REFUTES     0.8986    0.1329    0.2316      3333
#        SUPPORTS     0.5605    0.7294    0.6339      3333
#
#        accuracy                         0.5781      9999
#       macro avg     0.6738    0.5781    0.5164      9999
#    weighted avg     0.6738    0.5781    0.5164      9999
#
# ===
# fever-xlnet-base-cased.dev
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.9932    0.9628    0.9778      3333
#         REFUTES     0.9432    0.9268    0.9349      3333
#        SUPPORTS     0.9227    0.9670    0.9443      3333
#
#        accuracy                         0.9522      9999
#       macro avg     0.9530    0.9522    0.9523      9999
#    weighted avg     0.9530    0.9522    0.9523      9999
#
# ===
# climatefever-xlnet-base-cased.dev
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.4300    0.9892    0.5994      3333
#         REFUTES     0.9429    0.1089    0.1953      3333
#        SUPPORTS     0.7138    0.4167    0.5262      3333
#
#        accuracy                         0.5050      9999
#       macro avg     0.6955    0.5050    0.4403      9999
#    weighted avg     0.6955    0.5050    0.4403      9999
#
# ===
# climatefeverpure-bert-base-uncased.dev
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.6540    0.8650    0.7449      3333
#         REFUTES     0.9162    0.1869    0.3105      3333
#        SUPPORTS     0.5634    0.8302    0.6713      3333
#
#        accuracy                         0.6274      9999
#       macro avg     0.7112    0.6274    0.5755      9999
#    weighted avg     0.7112    0.6274    0.5755      9999
#
# ===
# fever-climatefeverpure-xlnet-base-cased.dev
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.9911    0.9643    0.9775      3333
#         REFUTES     0.9432    0.9268    0.9349      3333
#        SUPPORTS     0.9242    0.9652    0.9442      3333
#
#        accuracy                         0.9521      9999
#       macro avg     0.9528    0.9521    0.9522      9999
#    weighted avg     0.9528    0.9521    0.9522      9999
#
# ===
# fever-bert-base-uncased.dev
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.9877    0.9841    0.9859      3333
#         REFUTES     0.9580    0.9181    0.9376      3333
#        SUPPORTS     0.9225    0.9643    0.9429      3333
#
#        accuracy                         0.9555      9999
#       macro avg     0.9561    0.9555    0.9555      9999
#    weighted avg     0.9561    0.9555    0.9555      9999
#
# ===
# climatefever-bert-base-uncased.dev
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.5913    0.9781    0.7371      3333
#         REFUTES     0.9468    0.1227    0.2173      3333
#        SUPPORTS     0.6411    0.7798    0.7037      3333
#
#        accuracy                         0.6269      9999
#       macro avg     0.7264    0.6269    0.5527      9999
#    weighted avg     0.7264    0.6269    0.5527      9999
#
# ===
# fever-climatefever-xlnet-base-cased.dev
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.9917    0.9628    0.9770      3333
#         REFUTES     0.9435    0.9277    0.9356      3333
#        SUPPORTS     0.9223    0.9646    0.9430      3333
#
#        accuracy                         0.9517      9999
#       macro avg     0.9525    0.9517    0.9518      9999
#    weighted avg     0.9525    0.9517    0.9518      9999
#
# ===

# %%
for score in majority_agg_res["climatefeverpure"]["dev"]:
    print(score._score_name)
    print(score.classification_report)
    print("===")
# Out:
# fever-climatefeverpure-bert-base-uncased.dev
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.4245    0.4737    0.4478        95
#         REFUTES     0.4000    0.4314    0.4151        51
#        SUPPORTS     0.7009    0.6212    0.6586       132
#
#        accuracy                         0.5360       278
#       macro avg     0.5085    0.5088    0.5072       278
#    weighted avg     0.5512    0.5360    0.5419       278
#
# ===
# fever-climatefever-bert-base-uncased.dev
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.4175    0.8526    0.5606        95
#         REFUTES     0.6111    0.2157    0.3188        51
#        SUPPORTS     0.8182    0.4091    0.5455       132
#
#        accuracy                         0.5252       278
#       macro avg     0.6156    0.4925    0.4749       278
#    weighted avg     0.6433    0.5252    0.5090       278
#
# ===
# climatefeverpure-xlnet-base-cased.dev
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.5248    0.5579    0.5408        95
#         REFUTES     0.6875    0.4314    0.5301        51
#        SUPPORTS     0.6690    0.7348    0.7004       132
#
#        accuracy                         0.6187       278
#       macro avg     0.6271    0.5747    0.5904       278
#    weighted avg     0.6231    0.6187    0.6146       278
#
# ===
# fever-xlnet-base-cased.dev
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.3226    0.1053    0.1587        95
#         REFUTES     0.3222    0.5686    0.4113        51
#        SUPPORTS     0.6178    0.7348    0.6713       132
#
#        accuracy                         0.4892       278
#       macro avg     0.4209    0.4696    0.4138       278
#    weighted avg     0.4627    0.4892    0.4484       278
#
# ===
# climatefever-xlnet-base-cased.dev
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.4595    0.7158    0.5597        95
#         REFUTES     0.8500    0.3333    0.4789        51
#        SUPPORTS     0.6909    0.5758    0.6281       132
#
#        accuracy                         0.5791       278
#       macro avg     0.6668    0.5416    0.5555       278
#    weighted avg     0.6410    0.5791    0.5773       278
#
# ===
# climatefeverpure-bert-base-uncased.dev
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.4928    0.3579    0.4146        95
#         REFUTES     0.4634    0.3725    0.4130        51
#        SUPPORTS     0.6310    0.8030    0.7067       132
#
#        accuracy                         0.5719       278
#       macro avg     0.5290    0.5112    0.5114       278
#    weighted avg     0.5530    0.5719    0.5530       278
#
# ===
# fever-climatefeverpure-xlnet-base-cased.dev
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.5352    0.4000    0.4578        95
#         REFUTES     0.6122    0.5882    0.6000        51
#        SUPPORTS     0.6772    0.8106    0.7379       132
#
#        accuracy                         0.6295       278
#       macro avg     0.6082    0.5996    0.5986       278
#    weighted avg     0.6168    0.6295    0.6169       278
#
# ===
# fever-bert-base-uncased.dev
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.2105    0.0421    0.0702        95
#         REFUTES     0.2661    0.6471    0.3771        51
#        SUPPORTS     0.6519    0.6667    0.6592       132
#
#        accuracy                         0.4496       278
#       macro avg     0.3762    0.4519    0.3688       278
#    weighted avg     0.4303    0.4496    0.4062       278
#
# ===
# climatefever-bert-base-uncased.dev
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.4774    0.7789    0.5920        95
#         REFUTES     0.7727    0.3333    0.4658        51
#        SUPPORTS     0.7129    0.5455    0.6180       132
#
#        accuracy                         0.5863       278
#       macro avg     0.6543    0.5526    0.5586       278
#    weighted avg     0.6434    0.5863    0.5812       278
#
# ===
# fever-climatefever-xlnet-base-cased.dev
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.5231    0.7158    0.6044        95
#         REFUTES     0.6923    0.5294    0.6000        51
#        SUPPORTS     0.7798    0.6439    0.7054       132
#
#        accuracy                         0.6475       278
#       macro avg     0.6651    0.6297    0.6366       278
#    weighted avg     0.6760    0.6475    0.6516       278
#
# ===

# %%
for score in majority_agg_res["climatefever"]["dev"]:
    print(score._score_name)
    print(score.classification_report)
    print("===")
# Out:
# fever-climatefeverpure-bert-base-uncased.dev
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.4787    0.4737    0.4762        95
#         REFUTES     0.3966    0.4510    0.4220        51
#        SUPPORTS     0.6905    0.6591    0.6744       132
#
#        accuracy                         0.5576       278
#       macro avg     0.5219    0.5279    0.5242       278
#    weighted avg     0.5642    0.5576    0.5604       278
#
# ===
# fever-climatefever-bert-base-uncased.dev
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.4402    0.8526    0.5806        95
#         REFUTES     0.6364    0.2745    0.3836        51
#        SUPPORTS     0.8194    0.4470    0.5784       132
#
#        accuracy                         0.5540       278
#       macro avg     0.6320    0.5247    0.5142       278
#    weighted avg     0.6563    0.5540    0.5434       278
#
# ===
# climatefeverpure-xlnet-base-cased.dev
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.5699    0.5579    0.5638        95
#         REFUTES     0.6154    0.4706    0.5333        51
#        SUPPORTS     0.6644    0.7348    0.6978       132
#
#        accuracy                         0.6259       278
#       macro avg     0.6166    0.5878    0.5983       278
#    weighted avg     0.6231    0.6259    0.6219       278
#
# ===
# fever-xlnet-base-cased.dev
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.4167    0.1053    0.1681        95
#         REFUTES     0.2843    0.5686    0.3791        51
#        SUPPORTS     0.5855    0.6742    0.6268       132
#
#        accuracy                         0.4604       278
#       macro avg     0.4288    0.4494    0.3913       278
#    weighted avg     0.4726    0.4604    0.4246       278
#
# ===
# climatefever-xlnet-base-cased.dev
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.4857    0.7158    0.5787        95
#         REFUTES     0.8095    0.3333    0.4722        51
#        SUPPORTS     0.7094    0.6288    0.6667       132
#
#        accuracy                         0.6043       278
#       macro avg     0.6682    0.5593    0.5725       278
#    weighted avg     0.6513    0.6043    0.6009       278
#
# ===
# climatefeverpure-bert-base-uncased.dev
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.5152    0.3579    0.4224        95
#         REFUTES     0.4444    0.3922    0.4167        51
#        SUPPORTS     0.6228    0.7879    0.6957       132
#
#        accuracy                         0.5683       278
#       macro avg     0.5275    0.5126    0.5116       278
#    weighted avg     0.5533    0.5683    0.5511       278
#
# ===
# fever-climatefeverpure-xlnet-base-cased.dev
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.5672    0.4000    0.4691        95
#         REFUTES     0.5962    0.6078    0.6019        51
#        SUPPORTS     0.6667    0.8030    0.7285       132
#
#        accuracy                         0.6295       278
#       macro avg     0.6100    0.6036    0.5999       278
#    weighted avg     0.6197    0.6295    0.6167       278
#
# ===
# fever-bert-base-uncased.dev
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.4444    0.0421    0.0769        95
#         REFUTES     0.2556    0.6667    0.3696        51
#        SUPPORTS     0.6324    0.6515    0.6418       132
#
#        accuracy                         0.4460       278
#       macro avg     0.4441    0.4534    0.3628       278
#    weighted avg     0.4990    0.4460    0.3988       278
#
# ===
# climatefever-bert-base-uncased.dev
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.5481    0.7789    0.6435        95
#         REFUTES     0.7200    0.3529    0.4737        51
#        SUPPORTS     0.7373    0.6591    0.6960       132
#
#        accuracy                         0.6439       278
#       macro avg     0.6685    0.5970    0.6044       278
#    weighted avg     0.6695    0.6439    0.6373       278
#
# ===
# fever-climatefever-xlnet-base-cased.dev
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.5620    0.7158    0.6296        95
#         REFUTES     0.6000    0.5294    0.5625        51
#        SUPPORTS     0.7857    0.6667    0.7213       132
#
#        accuracy                         0.6583       278
#       macro avg     0.6492    0.6373    0.6378       278
#    weighted avg     0.6752    0.6583    0.6608       278
#
# ===

# %%
for score in majority_agg_res["scifact"]["all"]:
    print(score._score_name)
    print(score.classification_report)
    print("===")
# Out:
# fever-climatefever-xlnet-base-cased.all
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.5433    0.3918    0.4553       416
#         REFUTES     0.4860    0.4388    0.4612       237
#        SUPPORTS     0.5613    0.7325    0.6356       456
#
#        accuracy                         0.5419      1109
#       macro avg     0.5302    0.5210    0.5174      1109
#    weighted avg     0.5385    0.5419    0.5307      1109
#
# ===
# climatefeverpure-bert-base-uncased.all
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.6125    0.1178    0.1976       416
#         REFUTES     0.3462    0.1519    0.2111       237
#        SUPPORTS     0.4411    0.8947    0.5909       456
#
#        accuracy                         0.4445      1109
#       macro avg     0.4666    0.3881    0.3332      1109
#    weighted avg     0.4851    0.4445    0.3622      1109
#
# ===
# climatefever-xlnet-base-cased.all
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.4533    0.4663    0.4597       416
#         REFUTES     0.4474    0.0717    0.1236       237
#        SUPPORTS     0.5023    0.7083    0.5878       456
#
#        accuracy                         0.4815      1109
#       macro avg     0.4677    0.4155    0.3904      1109
#    weighted avg     0.4722    0.4815    0.4406      1109
#
# ===
# fever-bert-base-uncased.all
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.5912    0.2260    0.3270       416
#         REFUTES     0.4069    0.5992    0.4846       237
#        SUPPORTS     0.5790    0.7632    0.6585       456
#
#        accuracy                         0.5266      1109
#       macro avg     0.5257    0.5294    0.4900      1109
#    weighted avg     0.5468    0.5266    0.4970      1109
#
# ===
# fever-climatefeverpure-bert-base-uncased.all
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.4816    0.2837    0.3570       416
#         REFUTES     0.4303    0.4557    0.4426       237
#        SUPPORTS     0.5481    0.7368    0.6286       456
#
#        accuracy                         0.5068      1109
#       macro avg     0.4867    0.4921    0.4761      1109
#    weighted avg     0.4980    0.5068    0.4870      1109
#
# ===
# fever-climatefever-bert-base-uncased.all
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.4955    0.3942    0.4391       416
#         REFUTES     0.4416    0.2869    0.3478       237
#        SUPPORTS     0.5401    0.7390    0.6241       456
#
#        accuracy                         0.5131      1109
#       macro avg     0.4924    0.4734    0.4703      1109
#    weighted avg     0.5023    0.5131    0.4956      1109
#
# ===
# climatefever-bert-base-uncased.all
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.5732    0.3293    0.4183       416
#         REFUTES     0.3896    0.1266    0.1911       237
#        SUPPORTS     0.4842    0.8421    0.6149       456
#
#        accuracy                         0.4968      1109
#       macro avg     0.4824    0.4327    0.4081      1109
#    weighted avg     0.4974    0.4968    0.4506      1109
#
# ===
# fever-xlnet-base-cased.all
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.5486    0.2308    0.3249       416
#         REFUTES     0.4764    0.4684    0.4723       237
#        SUPPORTS     0.5364    0.8246    0.6500       456
#
#        accuracy                         0.5257      1109
#       macro avg     0.5204    0.5079    0.4824      1109
#    weighted avg     0.5281    0.5257    0.4901      1109
#
# ===
# fever-climatefeverpure-xlnet-base-cased.all
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.5226    0.2500    0.3382       416
#         REFUTES     0.5128    0.4219    0.4630       237
#        SUPPORTS     0.5203    0.8158    0.6354       456
#
#        accuracy                         0.5194      1109
#       macro avg     0.5186    0.4959    0.4788      1109
#    weighted avg     0.5196    0.5194    0.4871      1109
#
# ===
# climatefeverpure-xlnet-base-cased.all
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.5043    0.2812    0.3611       416
#         REFUTES     0.4951    0.2152    0.3000       237
#        SUPPORTS     0.4729    0.8026    0.5951       456
#
#        accuracy                         0.4815      1109
#       macro avg     0.4908    0.4330    0.4187      1109
#    weighted avg     0.4894    0.4815    0.4443      1109
#
# ===

# %%
for score in majority_agg_res["scifact"]["dev"]:
    print(score._score_name)
    print(score.classification_report)
    print("===")
# Out:
# fever-climatefeverpure-bert-base-uncased.dev
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.4776    0.2857    0.3575       112
#         REFUTES     0.4098    0.3906    0.4000        64
#        SUPPORTS     0.5581    0.7742    0.6486       124
#
#        accuracy                         0.5100       300
#       macro avg     0.4819    0.4835    0.4687       300
#    weighted avg     0.4964    0.5100    0.4869       300
#
# ===
# fever-climatefever-bert-base-uncased.dev
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.5169    0.4107    0.4577       112
#         REFUTES     0.4167    0.2344    0.3000        64
#        SUPPORTS     0.5543    0.7823    0.6488       124
#
#        accuracy                         0.5267       300
#       macro avg     0.4959    0.4758    0.4688       300
#    weighted avg     0.5110    0.5267    0.5031       300
#
# ===
# climatefeverpure-xlnet-base-cased.dev
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.5000    0.2946    0.3708       112
#         REFUTES     0.3214    0.1406    0.1957        64
#        SUPPORTS     0.4660    0.7742    0.5818       124
#
#        accuracy                         0.4600       300
#       macro avg     0.4291    0.4032    0.3828       300
#    weighted avg     0.4479    0.4600    0.4207       300
#
# ===
# fever-xlnet-base-cased.dev
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.5217    0.2143    0.3038       112
#         REFUTES     0.4590    0.4375    0.4480        64
#        SUPPORTS     0.5285    0.8226    0.6435       124
#
#        accuracy                         0.5133       300
#       macro avg     0.5031    0.4915    0.4651       300
#    weighted avg     0.5112    0.5133    0.4750       300
#
# ===
# climatefever-xlnet-base-cased.dev
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.4915    0.5179    0.5043       112
#         REFUTES     0.2500    0.0469    0.0789        64
#        SUPPORTS     0.5294    0.7258    0.6122       124
#
#        accuracy                         0.5033       300
#       macro avg     0.4236    0.4302    0.3985       300
#    weighted avg     0.4557    0.5033    0.4582       300
#
# ===
# climatefeverpure-bert-base-uncased.dev
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.6154    0.1429    0.2319       112
#         REFUTES     0.2593    0.1094    0.1538        64
#        SUPPORTS     0.4413    0.8790    0.5876       124
#
#        accuracy                         0.4400       300
#       macro avg     0.4386    0.3771    0.3244       300
#    weighted avg     0.4675    0.4400    0.3623       300
#
# ===
# fever-climatefeverpure-xlnet-base-cased.dev
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.6071    0.3036    0.4048       112
#         REFUTES     0.5745    0.4219    0.4865        64
#        SUPPORTS     0.5279    0.8387    0.6480       124
#
#        accuracy                         0.5500       300
#       macro avg     0.5698    0.5214    0.5131       300
#    weighted avg     0.5674    0.5500    0.5227       300
#
# ===
# fever-bert-base-uncased.dev
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.6190    0.2321    0.3377       112
#         REFUTES     0.3978    0.5781    0.4713        64
#        SUPPORTS     0.5879    0.7823    0.6713       124
#
#        accuracy                         0.5333       300
#       macro avg     0.5349    0.5308    0.4934       300
#    weighted avg     0.5590    0.5333    0.5041       300
#
# ===
# climatefever-bert-base-uncased.dev
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.5429    0.3393    0.4176       112
#         REFUTES     0.2083    0.0781    0.1136        64
#        SUPPORTS     0.4854    0.8065    0.6061       124
#
#        accuracy                         0.4767       300
#       macro avg     0.4122    0.4080    0.3791       300
#    weighted avg     0.4478    0.4767    0.4306       300
#
# ===
# fever-climatefever-xlnet-base-cased.dev
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.5595    0.4196    0.4796       112
#         REFUTES     0.5319    0.3906    0.4505        64
#        SUPPORTS     0.5621    0.7661    0.6485       124
#
#        accuracy                         0.5567       300
#       macro avg     0.5512    0.5255    0.5262       300
#    weighted avg     0.5547    0.5567    0.5432       300
#
# ===

# %%
for score in majority_agg_res["scifactpipeline"]["all"]:
    print(score._score_name)
    print(score.fever_score)
    print(score.classification_report)
    print("===")
# Out:
# fever-climatefever-xlnet-base-cased.all
# 0.4003606853020739
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.6149    0.2572    0.3627       416
#         REFUTES     0.4350    0.4515    0.4431       237
#        SUPPORTS     0.5210    0.7873    0.6271       456
#
#        accuracy                         0.5167      1109
#       macro avg     0.5236    0.4987    0.4776      1109
#    weighted avg     0.5379    0.5167    0.4886      1109
#
# ===
# climatefeverpure-bert-base-uncased.all
# 0.3309287646528404
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.8537    0.0841    0.1532       416
#         REFUTES     0.3423    0.1603    0.2184       237
#        SUPPORTS     0.4368    0.9167    0.5916       456
#
#        accuracy                         0.4427      1109
#       macro avg     0.5443    0.3870    0.3211      1109
#    weighted avg     0.5730    0.4427    0.3474      1109
#
# ===
# climatefever-xlnet-base-cased.all
# 0.3985572587917042
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.5520    0.3702    0.4432       416
#         REFUTES     0.3966    0.0970    0.1559       237
#        SUPPORTS     0.4909    0.8311    0.6173       456
#
#        accuracy                         0.5014      1109
#       macro avg     0.4798    0.4328    0.4055      1109
#    weighted avg     0.4937    0.5014    0.4534      1109
#
# ===
# fever-bert-base-uncased.all
# 0.3327321911632101
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.9091    0.0481    0.0913       416
#         REFUTES     0.3318    0.5992    0.4271       237
#        SUPPORTS     0.5159    0.7456    0.6099       456
#
#        accuracy                         0.4527      1109
#       macro avg     0.5856    0.4643    0.3761      1109
#    weighted avg     0.6241    0.4527    0.3763      1109
#
# ===
# fever-climatefeverpure-bert-base-uncased.all
# 0.3742110009017133
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.6555    0.1875    0.2916       416
#         REFUTES     0.3686    0.5148    0.4296       237
#        SUPPORTS     0.5250    0.7588    0.6206       456
#
#        accuracy                         0.4923      1109
#       macro avg     0.5164    0.4870    0.4473      1109
#    weighted avg     0.5405    0.4923    0.4564      1109
#
# ===
# fever-climatefever-bert-base-uncased.all
# 0.4012623985572588
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.6269    0.3029    0.4084       416
#         REFUTES     0.3918    0.3207    0.3527       237
#        SUPPORTS     0.5168    0.8092    0.6308       456
#
#        accuracy                         0.5149      1109
#       macro avg     0.5118    0.4776    0.4640      1109
#    weighted avg     0.5314    0.5149    0.4879      1109
#
# ===
# climatefever-bert-base-uncased.all
# 0.39495040577096485
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.7721    0.2524    0.3804       416
#         REFUTES     0.3889    0.1477    0.2141       237
#        SUPPORTS     0.4666    0.9035    0.6154       456
#
#        accuracy                         0.4977      1109
#       macro avg     0.5425    0.4345    0.4033      1109
#    weighted avg     0.5646    0.4977    0.4415      1109
#
# ===
# fever-xlnet-base-cased.all
# 0.3462578899909829
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.5111    0.0553    0.0998       416
#         REFUTES     0.3778    0.4304    0.4024       237
#        SUPPORTS     0.4874    0.8487    0.6192       456
#
#        accuracy                         0.4617      1109
#       macro avg     0.4588    0.4448    0.3738      1109
#    weighted avg     0.4729    0.4617    0.3780      1109
#
# ===
# fever-climatefeverpure-xlnet-base-cased.all
# 0.3606853020739405
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.6364    0.1346    0.2222       416
#         REFUTES     0.4366    0.3924    0.4133       237
#        SUPPORTS     0.4790    0.8487    0.6123       456
#
#        accuracy                         0.4833      1109
#       macro avg     0.5173    0.4586    0.4160      1109
#    weighted avg     0.5290    0.4833    0.4235      1109
#
# ===
# climatefeverpure-xlnet-base-cased.all
# 0.38052299368800724
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.6575    0.2308    0.3416       416
#         REFUTES     0.4407    0.2194    0.2930       237
#        SUPPORTS     0.4698    0.8706    0.6103       456
#
#        accuracy                         0.4914      1109
#       macro avg     0.5227    0.4403    0.4150      1109
#    weighted avg     0.5340    0.4914    0.4417      1109
#
# ===

# %%
for score in majority_agg_res["scifactpipeline"]["dev"]:
    print(score._score_name)
    print(score.fever_score)
    print(score.classification_report)
    print("===")
# Out:
# fever-climatefeverpure-bert-base-uncased.dev
# 0.35
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.6000    0.1607    0.2535       112
#         REFUTES     0.3478    0.5000    0.4103        64
#        SUPPORTS     0.5281    0.7581    0.6225       124
#
#        accuracy                         0.4800       300
#       macro avg     0.4920    0.4729    0.4288       300
#    weighted avg     0.5165    0.4800    0.4395       300
#
# ===
# fever-climatefever-bert-base-uncased.dev
# 0.38
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.5763    0.3036    0.3977       112
#         REFUTES     0.3261    0.2344    0.2727        64
#        SUPPORTS     0.5026    0.7903    0.6144       124
#
#        accuracy                         0.4900       300
#       macro avg     0.4683    0.4428    0.4283       300
#    weighted avg     0.4924    0.4900    0.4606       300
#
# ===
# climatefeverpure-xlnet-base-cased.dev
# 0.35333333333333333
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.6486    0.2143    0.3221       112
#         REFUTES     0.3143    0.1719    0.2222        64
#        SUPPORTS     0.4561    0.8387    0.5909       124
#
#        accuracy                         0.4633       300
#       macro avg     0.4730    0.4083    0.3784       300
#    weighted avg     0.4977    0.4633    0.4119       300
#
# ===
# fever-xlnet-base-cased.dev
# 0.34
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.4167    0.0446    0.0806       112
#         REFUTES     0.3478    0.3750    0.3609        64
#        SUPPORTS     0.4932    0.8710    0.6297       124
#
#        accuracy                         0.4567       300
#       macro avg     0.4192    0.4302    0.3571       300
#    weighted avg     0.4336    0.4567    0.3674       300
#
# ===
# climatefever-xlnet-base-cased.dev
# 0.3933333333333333
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.5541    0.3661    0.4409       112
#         REFUTES     0.2105    0.0625    0.0964        64
#        SUPPORTS     0.4879    0.8145    0.6103       124
#
#        accuracy                         0.4867       300
#       macro avg     0.4175    0.4144    0.3825       300
#    weighted avg     0.4534    0.4867    0.4374       300
#
# ===
# climatefeverpure-bert-base-uncased.dev
# 0.32
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.9000    0.0804    0.1475       112
#         REFUTES     0.2500    0.1094    0.1522        64
#        SUPPORTS     0.4237    0.8952    0.5751       124
#
#        accuracy                         0.4233       300
#       macro avg     0.5246    0.3616    0.2916       300
#    weighted avg     0.5644    0.4233    0.3253       300
#
# ===
# fever-climatefeverpure-xlnet-base-cased.dev
# 0.35333333333333333
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.5652    0.1161    0.1926       112
#         REFUTES     0.4808    0.3906    0.4310        64
#        SUPPORTS     0.4800    0.8710    0.6189       124
#
#        accuracy                         0.4867       300
#       macro avg     0.5087    0.4592    0.4142       300
#    weighted avg     0.5120    0.4867    0.4197       300
#
# ===
# fever-bert-base-uncased.dev
# 0.32
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     1.0000    0.0625    0.1176       112
#         REFUTES     0.3193    0.5938    0.4153        64
#        SUPPORTS     0.5230    0.7339    0.6107       124
#
#        accuracy                         0.4533       300
#       macro avg     0.6141    0.4634    0.3812       300
#    weighted avg     0.6576    0.4533    0.3850       300
#
# ===
# climatefever-bert-base-uncased.dev
# 0.36666666666666664
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.6667    0.2321    0.3444       112
#         REFUTES     0.2500    0.1094    0.1522        64
#        SUPPORTS     0.4506    0.8468    0.5882       124
#
#        accuracy                         0.4600       300
#       macro avg     0.4558    0.3961    0.3616       300
#    weighted avg     0.4885    0.4600    0.4042       300
#
# ===
# fever-climatefever-xlnet-base-cased.dev
# 0.4
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.6038    0.2857    0.3879       112
#         REFUTES     0.4310    0.3906    0.4098        64
#        SUPPORTS     0.5397    0.8226    0.6518       124
#
#        accuracy                         0.5300       300
#       macro avg     0.5248    0.4996    0.4832       300
#    weighted avg     0.5404    0.5300    0.5016       300
#
# ===

# %% [markdown]
# ### Mean probability

# %%
meanproba_agg_res = {
    "fever": defaultdict(list), 
    "climatefeverpure": defaultdict(list), 
    "scifact": defaultdict(list),
    "climatefever": defaultdict(list),
    "scifactpipeline": defaultdict(list)
}

for actual_dp in tqdm(actual_pls):
    dataset = actual_dp.parent.stem.split("-")[0]
    split = actual_dp.stem.split(".")[0]
    actual_data = read_data(actual_dp)
    if "climatefever" in dataset:
        score_obj = scorer.ClimateFEVERScorer
    else:
        score_obj = scorer.FEVERScorer
        
    for pp in pred_p.joinpath("sent", dataset).glob(f"*.{split}.jsonl"):
        preds = read_data(pp)
        
        # aggregate
        preds = pd.DataFrame(preds)
        preds = preds.groupby("claim_id", sort=False, as_index=False).agg({"predicted_proba": aggregate.agg_predict_proba})
        preds = preds.rename(columns={"predicted_proba": "predicted_label"})
        preds["predicted_label"] = preds["predicted_label"].map(constants.ID2LABEL)
        preds = preds.to_dict("records")
        
        assert all([int(a["id"]) == int(p["claim_id"].split("|")[1]) for a, p in zip(actual_data, preds)])
        
        meanproba_agg_res[dataset][split].append(score_obj(
            actual_data=actual_data, 
            prediction_data=preds, 
            oracle_rte=False, 
            oracle_ir=True, 
            max_evidence=99999, 
            score_name=pp.stem
        ))
    if dataset == "scifact":
        dataset = "scifactpipeline"
        for pp in pred_p.joinpath("sent", dataset).glob(f"*.{split}.jsonl"):
            preds = read_data(pp)

            # aggregate
            preds = pd.DataFrame(preds)
            preds = preds.groupby("claim_id", sort=False, as_index=False).agg({
                "predicted_proba": aggregate.agg_predict_proba,
                "predicted_evidence": lambda ls: [i for i in ls]
            })
            preds = preds.rename(columns={"predicted_proba": "predicted_label"})
            preds["predicted_label"] = preds["predicted_label"].map(constants.ID2LABEL)
            preds = preds.to_dict("records")
            
            assert all([int(a["id"]) == int(p["claim_id"].split("|")[1]) for a, p in zip(actual_data, preds)])
            
            meanproba_agg_res[dataset][split].append(score_obj(
                actual_data=actual_data, 
                prediction_data=preds, 
                oracle_rte=False, 
                oracle_ir=False, 
                max_evidence=99999, 
                score_name=pp.stem
            ))
# Out:
# 100%|██████████| 9/9 [00:34<00:00,  3.78s/it]

# %%
with result_p.joinpath("sent_macro_verdict_meanproba_metrics.pkl").open("wb") as fn:
    pkl.dump(meanproba_agg_res, fn)

# %%
for score in meanproba_agg_res["fever"]["dev"]:
    print(score._score_name)
    print(score.classification_report)
    print("===")
# Out:
# fever-climatefeverpure-bert-base-uncased.dev
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.9884    0.9961    0.9922      3333
#         REFUTES     0.9627    0.9130    0.9372      3333
#        SUPPORTS     0.9235    0.9640    0.9433      3333
#
#        accuracy                         0.9577      9999
#       macro avg     0.9582    0.9577    0.9576      9999
#    weighted avg     0.9582    0.9577    0.9576      9999
#
# ===
# fever-climatefever-bert-base-uncased.dev
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.9863    0.9952    0.9907      3333
#         REFUTES     0.9602    0.9121    0.9355      3333
#        SUPPORTS     0.9256    0.9637    0.9443      3333
#
#        accuracy                         0.9570      9999
#       macro avg     0.9574    0.9570    0.9569      9999
#    weighted avg     0.9574    0.9570    0.9569      9999
#
# ===
# climatefeverpure-xlnet-base-cased.dev
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.5426    0.9181    0.6821      3333
#         REFUTES     0.9056    0.1122    0.1997      3333
#        SUPPORTS     0.5837    0.6913    0.6330      3333
#
#        accuracy                         0.5739      9999
#       macro avg     0.6773    0.5739    0.5049      9999
#    weighted avg     0.6773    0.5739    0.5049      9999
#
# ===
# fever-xlnet-base-cased.dev
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.9958    0.9874    0.9916      3333
#         REFUTES     0.9587    0.9265    0.9423      3333
#        SUPPORTS     0.9283    0.9673    0.9474      3333
#
#        accuracy                         0.9604      9999
#       macro avg     0.9609    0.9604    0.9604      9999
#    weighted avg     0.9609    0.9604    0.9604      9999
#
# ===
# climatefever-xlnet-base-cased.dev
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.4168    0.9958    0.5876      3333
#         REFUTES     0.9527    0.0906    0.1655      3333
#        SUPPORTS     0.7189    0.3705    0.4890      3333
#
#        accuracy                         0.4856      9999
#       macro avg     0.6961    0.4856    0.4140      9999
#    weighted avg     0.6961    0.4856    0.4140      9999
#
# ===
# climatefeverpure-bert-base-uncased.dev
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.6324    0.9280    0.7522      3333
#         REFUTES     0.9264    0.1698    0.2870      3333
#        SUPPORTS     0.5882    0.7936    0.6756      3333
#
#        accuracy                         0.6305      9999
#       macro avg     0.7156    0.6305    0.5716      9999
#    weighted avg     0.7156    0.6305    0.5716      9999
#
# ===
# fever-climatefeverpure-xlnet-base-cased.dev
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.9949    0.9877    0.9913      3333
#         REFUTES     0.9587    0.9274    0.9428      3333
#        SUPPORTS     0.9299    0.9670    0.9481      3333
#
#        accuracy                         0.9607      9999
#       macro avg     0.9612    0.9607    0.9607      9999
#    weighted avg     0.9612    0.9607    0.9607      9999
#
# ===
# fever-bert-base-uncased.dev
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.9896    0.9958    0.9927      3333
#         REFUTES     0.9640    0.9160    0.9394      3333
#        SUPPORTS     0.9252    0.9655    0.9449      3333
#
#        accuracy                         0.9591      9999
#       macro avg     0.9596    0.9591    0.9590      9999
#    weighted avg     0.9596    0.9591    0.9590      9999
#
# ===
# climatefever-bert-base-uncased.dev
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.5583    0.9931    0.7147      3333
#         REFUTES     0.9621    0.0990    0.1795      3333
#        SUPPORTS     0.6541    0.7315    0.6907      3333
#
#        accuracy                         0.6079      9999
#       macro avg     0.7248    0.6079    0.5283      9999
#    weighted avg     0.7248    0.6079    0.5283      9999
#
# ===
# fever-climatefever-xlnet-base-cased.dev
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.9946    0.9883    0.9914      3333
#         REFUTES     0.9602    0.9271    0.9434      3333
#        SUPPORTS     0.9288    0.9667    0.9474      3333
#
#        accuracy                         0.9607      9999
#       macro avg     0.9612    0.9607    0.9607      9999
#    weighted avg     0.9612    0.9607    0.9607      9999
#
# ===

# %%
for score in meanproba_agg_res["climatefeverpure"]["dev"]:
    print(score._score_name)
    print(score.classification_report)
    print("===")
# Out:
# fever-climatefeverpure-bert-base-uncased.dev
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.4870    0.7895    0.6024        95
#         REFUTES     0.4750    0.3725    0.4176        51
#        SUPPORTS     0.8571    0.5455    0.6667       132
#
#        accuracy                         0.5971       278
#       macro avg     0.6064    0.5692    0.5622       278
#    weighted avg     0.6606    0.5971    0.5990       278
#
# ===
# fever-climatefever-bert-base-uncased.dev
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.4115    0.9789    0.5794        95
#         REFUTES     0.8000    0.1569    0.2623        51
#        SUPPORTS     0.9286    0.2955    0.4483       132
#
#        accuracy                         0.5036       278
#       macro avg     0.7134    0.4771    0.4300       278
#    weighted avg     0.7283    0.5036    0.4590       278
#
# ===
# climatefeverpure-xlnet-base-cased.dev
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.5378    0.6737    0.5981        95
#         REFUTES     0.7333    0.4314    0.5432        51
#        SUPPORTS     0.7054    0.6894    0.6973       132
#
#        accuracy                         0.6367       278
#       macro avg     0.6589    0.5982    0.6129       278
#    weighted avg     0.6533    0.6367    0.6352       278
#
# ===
# fever-xlnet-base-cased.dev
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.5385    0.2947    0.3810        95
#         REFUTES     0.3659    0.5882    0.4511        51
#        SUPPORTS     0.6528    0.7121    0.6812       132
#
#        accuracy                         0.5468       278
#       macro avg     0.5190    0.5317    0.5044       278
#    weighted avg     0.5611    0.5468    0.5364       278
#
# ===
# climatefever-xlnet-base-cased.dev
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.4451    0.8526    0.5848        95
#         REFUTES     0.8000    0.2353    0.3636        51
#        SUPPORTS     0.7531    0.4621    0.5728       132
#
#        accuracy                         0.5540       278
#       macro avg     0.6660    0.5167    0.5071       278
#    weighted avg     0.6564    0.5540    0.5385       278
#
# ===
# climatefeverpure-bert-base-uncased.dev
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.5941    0.6316    0.6122        95
#         REFUTES     0.5625    0.3529    0.4337        51
#        SUPPORTS     0.7034    0.7727    0.7365       132
#
#        accuracy                         0.6475       278
#       macro avg     0.6200    0.5857    0.5941       278
#    weighted avg     0.6402    0.6475    0.6385       278
#
# ===
# fever-climatefeverpure-xlnet-base-cased.dev
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.5825    0.6316    0.6061        95
#         REFUTES     0.6744    0.5686    0.6170        51
#        SUPPORTS     0.7424    0.7424    0.7424       132
#
#        accuracy                         0.6727       278
#       macro avg     0.6665    0.6475    0.6552       278
#    weighted avg     0.6753    0.6727    0.6728       278
#
# ===
# fever-bert-base-uncased.dev
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.6786    0.2000    0.3089        95
#         REFUTES     0.2727    0.6471    0.3837        51
#        SUPPORTS     0.6899    0.6742    0.6820       132
#
#        accuracy                         0.5072       278
#       macro avg     0.5471    0.5071    0.4582       278
#    weighted avg     0.6095    0.5072    0.4998       278
#
# ===
# climatefever-bert-base-uncased.dev
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.4631    0.9895    0.6309        95
#         REFUTES     0.7778    0.2745    0.4058        51
#        SUPPORTS     0.8947    0.3864    0.5397       132
#
#        accuracy                         0.5719       278
#       macro avg     0.7119    0.5501    0.5255       278
#    weighted avg     0.7258    0.5719    0.5463       278
#
# ===
# fever-climatefever-xlnet-base-cased.dev
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.5116    0.9263    0.6592        95
#         REFUTES     0.8333    0.3922    0.5333        51
#        SUPPORTS     0.8659    0.5379    0.6636       132
#
#        accuracy                         0.6439       278
#       macro avg     0.7369    0.6188    0.6187       278
#    weighted avg     0.7388    0.6439    0.6382       278
#
# ===

# %%
for score in meanproba_agg_res["climatefever"]["dev"]:
    print(score._score_name)
    print(score.classification_report)
    print("===")
# Out:
# fever-climatefeverpure-bert-base-uncased.dev
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.4491    0.7895    0.5725        95
#         REFUTES     0.4595    0.3333    0.3864        51
#        SUPPORTS     0.8378    0.4697    0.6019       132
#
#        accuracy                         0.5540       278
#       macro avg     0.5821    0.5308    0.5203       278
#    weighted avg     0.6356    0.5540    0.5523       278
#
# ===
# fever-climatefever-bert-base-uncased.dev
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.3843    0.9789    0.5519        95
#         REFUTES     0.6250    0.0980    0.1695        51
#        SUPPORTS     0.8929    0.1894    0.3125       132
#
#        accuracy                         0.4424       278
#       macro avg     0.6341    0.4221    0.3446       278
#    weighted avg     0.6699    0.4424    0.3681       278
#
# ===
# climatefeverpure-xlnet-base-cased.dev
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.5333    0.6737    0.5953        95
#         REFUTES     0.6571    0.4510    0.5349        51
#        SUPPORTS     0.6911    0.6439    0.6667       132
#
#        accuracy                         0.6187       278
#       macro avg     0.6272    0.5895    0.5990       278
#    weighted avg     0.6309    0.6187    0.6181       278
#
# ===
# fever-xlnet-base-cased.dev
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.4912    0.2947    0.3684        95
#         REFUTES     0.3444    0.6078    0.4397        51
#        SUPPORTS     0.6183    0.6136    0.6160       132
#
#        accuracy                         0.5036       278
#       macro avg     0.4847    0.5054    0.4747       278
#    weighted avg     0.5246    0.5036    0.4990       278
#
# ===
# climatefever-xlnet-base-cased.dev
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.4263    0.8526    0.5684        95
#         REFUTES     0.8000    0.2353    0.3636        51
#        SUPPORTS     0.7671    0.4242    0.5463       132
#
#        accuracy                         0.5360       278
#       macro avg     0.6645    0.5041    0.4928       278
#    weighted avg     0.6567    0.5360    0.5204       278
#
# ===
# climatefeverpure-bert-base-uncased.dev
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.5769    0.6316    0.6030        95
#         REFUTES     0.5758    0.3725    0.4524        51
#        SUPPORTS     0.6879    0.7348    0.7106       132
#
#        accuracy                         0.6331       278
#       macro avg     0.6135    0.5797    0.5887       278
#    weighted avg     0.6294    0.6331    0.6265       278
#
# ===
# fever-climatefeverpure-xlnet-base-cased.dev
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.5000    0.6316    0.5581        95
#         REFUTES     0.6098    0.4902    0.5435        51
#        SUPPORTS     0.7094    0.6288    0.6667       132
#
#        accuracy                         0.6043       278
#       macro avg     0.6064    0.5835    0.5894       278
#    weighted avg     0.6196    0.6043    0.6070       278
#
# ===
# fever-bert-base-uncased.dev
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.6129    0.2000    0.3016        95
#         REFUTES     0.2698    0.6667    0.3842        51
#        SUPPORTS     0.6694    0.6136    0.6403       132
#
#        accuracy                         0.4820       278
#       macro avg     0.5174    0.4934    0.4420       278
#    weighted avg     0.5768    0.4820    0.4776       278
#
# ===
# climatefever-bert-base-uncased.dev
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.4105    0.9895    0.5802        95
#         REFUTES     0.8333    0.1961    0.3175        51
#        SUPPORTS     0.9459    0.2652    0.4142       132
#
#        accuracy                         0.5000       278
#       macro avg     0.7299    0.4836    0.4373       278
#    weighted avg     0.7423    0.5000    0.4532       278
#
# ===
# fever-climatefever-xlnet-base-cased.dev
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.4251    0.9263    0.5828        95
#         REFUTES     0.7333    0.2157    0.3333        51
#        SUPPORTS     0.8393    0.3561    0.5000       132
#
#        accuracy                         0.5252       278
#       macro avg     0.6659    0.4994    0.4720       278
#    weighted avg     0.6783    0.5252    0.4977       278
#
# ===

# %%
for score in meanproba_agg_res["scifact"]["all"]:
    print(score._score_name)
    print(score.classification_report)
    print("===")
# Out:
# fever-climatefever-xlnet-base-cased.all
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.5029    0.4183    0.4567       416
#         REFUTES     0.4680    0.4008    0.4318       237
#        SUPPORTS     0.5661    0.6952    0.6240       456
#
#        accuracy                         0.5284      1109
#       macro avg     0.5123    0.5048    0.5042      1109
#    weighted avg     0.5214    0.5284    0.5202      1109
#
# ===
# climatefeverpure-bert-base-uncased.all
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.6703    0.1466    0.2406       416
#         REFUTES     0.3571    0.1477    0.2090       237
#        SUPPORTS     0.4424    0.8925    0.5916       456
#
#        accuracy                         0.4536      1109
#       macro avg     0.4900    0.3956    0.3471      1109
#    weighted avg     0.5097    0.4536    0.3782      1109
#
# ===
# climatefever-xlnet-base-cased.all
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.4540    0.5817    0.5100       416
#         REFUTES     0.5385    0.0591    0.1065       237
#        SUPPORTS     0.5200    0.6272    0.5686       456
#
#        accuracy                         0.4887      1109
#       macro avg     0.5042    0.4227    0.3950      1109
#    weighted avg     0.4992    0.4887    0.4479      1109
#
# ===
# fever-bert-base-uncased.all
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.2581    0.0577    0.0943       416
#         REFUTES     0.3624    0.5781    0.4455       237
#        SUPPORTS     0.5345    0.7478    0.6234       456
#
#        accuracy                         0.4527      1109
#       macro avg     0.3850    0.4612    0.3877      1109
#    weighted avg     0.3940    0.4527    0.3869      1109
#
# ===
# fever-climatefeverpure-bert-base-uncased.all
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.4515    0.3245    0.3776       416
#         REFUTES     0.4194    0.4388    0.4289       237
#        SUPPORTS     0.5498    0.6776    0.6071       456
#
#        accuracy                         0.4941      1109
#       macro avg     0.4736    0.4803    0.4712      1109
#    weighted avg     0.4851    0.4941    0.4829      1109
#
# ===
# fever-climatefever-bert-base-uncased.all
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.4601    0.4712    0.4656       416
#         REFUTES     0.4597    0.2405    0.3158       237
#        SUPPORTS     0.5474    0.6711    0.6030       456
#
#        accuracy                         0.5041      1109
#       macro avg     0.4891    0.4609    0.4614      1109
#    weighted avg     0.4959    0.5041    0.4900      1109
#
# ===
# climatefever-bert-base-uncased.all
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.5371    0.4351    0.4807       416
#         REFUTES     0.3906    0.1055    0.1661       237
#        SUPPORTS     0.5000    0.7763    0.6082       456
#
#        accuracy                         0.5050      1109
#       macro avg     0.4759    0.4390    0.4184      1109
#    weighted avg     0.4905    0.5050    0.4659      1109
#
# ===
# fever-xlnet-base-cased.all
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.3540    0.0962    0.1512       416
#         REFUTES     0.4046    0.4473    0.4248       237
#        SUPPORTS     0.5109    0.8224    0.6303       456
#
#        accuracy                         0.4698      1109
#       macro avg     0.4232    0.4553    0.4021      1109
#    weighted avg     0.4293    0.4698    0.4067      1109
#
# ===
# fever-climatefeverpure-xlnet-base-cased.all
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.4789    0.2452    0.3243       416
#         REFUTES     0.4897    0.4008    0.4408       237
#        SUPPORTS     0.5100    0.7851    0.6183       456
#
#        accuracy                         0.5005      1109
#       macro avg     0.4928    0.4770    0.4612      1109
#    weighted avg     0.4940    0.5005    0.4701      1109
#
# ===
# climatefeverpure-xlnet-base-cased.all
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.5133    0.3702    0.4302       416
#         REFUTES     0.5181    0.1814    0.2687       237
#        SUPPORTS     0.4890    0.7785    0.6007       456
#
#        accuracy                         0.4977      1109
#       macro avg     0.5068    0.4434    0.4332      1109
#    weighted avg     0.5043    0.4977    0.4658      1109
#
# ===

# %%
for score in meanproba_agg_res["scifact"]["dev"]:
    print(score._score_name)
    print(score.classification_report)
    print("===")
# Out:
# fever-climatefeverpure-bert-base-uncased.dev
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.4533    0.3036    0.3636       112
#         REFUTES     0.3824    0.4062    0.3939        64
#        SUPPORTS     0.5732    0.7258    0.6406       124
#
#        accuracy                         0.5000       300
#       macro avg     0.4696    0.4785    0.4660       300
#    weighted avg     0.4878    0.5000    0.4846       300
#
# ===
# fever-climatefever-bert-base-uncased.dev
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.4911    0.4911    0.4911       112
#         REFUTES     0.4138    0.1875    0.2581        64
#        SUPPORTS     0.5597    0.7177    0.6290       124
#
#        accuracy                         0.5200       300
#       macro avg     0.4882    0.4654    0.4594       300
#    weighted avg     0.5030    0.5200    0.4984       300
#
# ===
# climatefeverpure-xlnet-base-cased.dev
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.5128    0.3571    0.4211       112
#         REFUTES     0.3846    0.1562    0.2222        64
#        SUPPORTS     0.4796    0.7581    0.5875       124
#
#        accuracy                         0.4800       300
#       macro avg     0.4590    0.4238    0.4103       300
#    weighted avg     0.4717    0.4800    0.4474       300
#
# ===
# fever-xlnet-base-cased.dev
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.4138    0.1071    0.1702       112
#         REFUTES     0.4265    0.4531    0.4394        64
#        SUPPORTS     0.5074    0.8306    0.6300       124
#
#        accuracy                         0.4800       300
#       macro avg     0.4492    0.4636    0.4132       300
#    weighted avg     0.4552    0.4800    0.4177       300
#
# ===
# climatefever-xlnet-base-cased.dev
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.4865    0.6429    0.5538       112
#         REFUTES     0.2222    0.0312    0.0548        64
#        SUPPORTS     0.5455    0.6290    0.5843       124
#
#        accuracy                         0.5067       300
#       macro avg     0.4181    0.4344    0.3976       300
#    weighted avg     0.4545    0.5067    0.4600       300
#
# ===
# climatefeverpure-bert-base-uncased.dev
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.6786    0.1696    0.2714       112
#         REFUTES     0.2857    0.1250    0.1739        64
#        SUPPORTS     0.4467    0.8790    0.5924       124
#
#        accuracy                         0.4533       300
#       macro avg     0.4703    0.3912    0.3459       300
#    weighted avg     0.4989    0.4533    0.3833       300
#
# ===
# fever-climatefeverpure-xlnet-base-cased.dev
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.5536    0.2768    0.3690       112
#         REFUTES     0.5200    0.4062    0.4561        64
#        SUPPORTS     0.5206    0.8145    0.6352       124
#
#        accuracy                         0.5267       300
#       macro avg     0.5314    0.4992    0.4868       300
#    weighted avg     0.5328    0.5267    0.4976       300
#
# ===
# fever-bert-base-uncased.dev
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.4091    0.0804    0.1343       112
#         REFUTES     0.3564    0.5625    0.4364        64
#        SUPPORTS     0.5424    0.7742    0.6379       124
#
#        accuracy                         0.4700       300
#       macro avg     0.4360    0.4724    0.4029       300
#    weighted avg     0.4529    0.4700    0.4069       300
#
# ===
# climatefever-bert-base-uncased.dev
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.5055    0.4107    0.4532       112
#         REFUTES     0.1818    0.0625    0.0930        64
#        SUPPORTS     0.4973    0.7500    0.5981       124
#
#        accuracy                         0.4767       300
#       macro avg     0.3949    0.4077    0.3814       300
#    weighted avg     0.4331    0.4767    0.4362       300
#
# ===
# fever-climatefever-xlnet-base-cased.dev
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.5393    0.4286    0.4776       112
#         REFUTES     0.5102    0.3906    0.4425        64
#        SUPPORTS     0.5679    0.7419    0.6434       124
#
#        accuracy                         0.5500       300
#       macro avg     0.5391    0.5204    0.5211       300
#    weighted avg     0.5449    0.5500    0.5386       300
#
# ===

# %%
for score in meanproba_agg_res["scifactpipeline"]["all"]:
    print(score._score_name)
    print(score.classification_report)
    print("===")
# Out:
# fever-climatefever-xlnet-base-cased.all
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.5611    0.5962    0.5781       416
#         REFUTES     0.4728    0.3671    0.4133       237
#        SUPPORTS     0.5942    0.6294    0.6113       456
#
#        accuracy                         0.5609      1109
#       macro avg     0.5427    0.5309    0.5342      1109
#    weighted avg     0.5558    0.5609    0.5565      1109
#
# ===
# climatefeverpure-bert-base-uncased.all
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.6630    0.1466    0.2402       416
#         REFUTES     0.3548    0.1392    0.2000       237
#        SUPPORTS     0.4437    0.8991    0.5942       456
#
#        accuracy                         0.4545      1109
#       macro avg     0.4872    0.3950    0.3448      1109
#    weighted avg     0.5070    0.4545    0.3772      1109
#
# ===
# climatefever-xlnet-base-cased.all
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.4911    0.6611    0.5635       416
#         REFUTES     0.3636    0.0338    0.0618       237
#        SUPPORTS     0.5427    0.6272    0.5819       456
#
#        accuracy                         0.5131      1109
#       macro avg     0.4658    0.4407    0.4024      1109
#    weighted avg     0.4851    0.5131    0.4639      1109
#
# ===
# fever-bert-base-uncased.all
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.9091    0.0721    0.1336       416
#         REFUTES     0.3262    0.5823    0.4182       237
#        SUPPORTS     0.5161    0.7390    0.6078       456
#
#        accuracy                         0.4554      1109
#       macro avg     0.5838    0.4645    0.3865      1109
#    weighted avg     0.6229    0.4554    0.3894      1109
#
# ===
# fever-climatefeverpure-bert-base-uncased.all
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.5514    0.3870    0.4548       416
#         REFUTES     0.3688    0.4388    0.4008       237
#        SUPPORTS     0.5514    0.6469    0.5954       456
#
#        accuracy                         0.5050      1109
#       macro avg     0.4905    0.4909    0.4836      1109
#    weighted avg     0.5124    0.5050    0.5010      1109
#
# ===
# fever-climatefever-bert-base-uncased.all
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.4934    0.5433    0.5172       416
#         REFUTES     0.4198    0.2321    0.2989       237
#        SUPPORTS     0.5596    0.6382    0.5963       456
#
#        accuracy                         0.5158      1109
#       macro avg     0.4910    0.4712    0.4708      1109
#    weighted avg     0.5049    0.5158    0.5031      1109
#
# ===
# climatefever-bert-base-uncased.all
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.5379    0.4952    0.5156       416
#         REFUTES     0.3830    0.0759    0.1268       237
#        SUPPORTS     0.5184    0.7719    0.6203       456
#
#        accuracy                         0.5194      1109
#       macro avg     0.4797    0.4477    0.4209      1109
#    weighted avg     0.4968    0.5194    0.4756      1109
#
# ===
# fever-xlnet-base-cased.all
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.7286    0.1226    0.2099       416
#         REFUTES     0.3878    0.4304    0.4080       237
#        SUPPORTS     0.5000    0.8509    0.6299       456
#
#        accuracy                         0.4878      1109
#       macro avg     0.5388    0.4680    0.4159      1109
#    weighted avg     0.5618    0.4878    0.4249      1109
#
# ===
# fever-climatefeverpure-xlnet-base-cased.all
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.6376    0.3341    0.4385       416
#         REFUTES     0.4308    0.3544    0.3889       237
#        SUPPORTS     0.5187    0.7917    0.6267       456
#
#        accuracy                         0.5266      1109
#       macro avg     0.5290    0.4934    0.4847      1109
#    weighted avg     0.5445    0.5266    0.5053      1109
#
# ===
# climatefeverpure-xlnet-base-cased.all
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.5593    0.3966    0.4641       416
#         REFUTES     0.4706    0.1688    0.2484       237
#        SUPPORTS     0.4911    0.7851    0.6042       456
#
#        accuracy                         0.5077      1109
#       macro avg     0.5070    0.4502    0.4389      1109
#    weighted avg     0.5123    0.5077    0.4756      1109
#
# ===

# %%
for score in meanproba_agg_res["scifactpipeline"]["dev"]:
    print(score._score_name)
    print(score.classification_report)
    print("===")
# Out:
# fever-climatefeverpure-bert-base-uncased.dev
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.4943    0.3839    0.4322       112
#         REFUTES     0.3200    0.3750    0.3453        64
#        SUPPORTS     0.5580    0.6210    0.5878       124
#
#        accuracy                         0.4800       300
#       macro avg     0.4574    0.4600    0.4551       300
#    weighted avg     0.4834    0.4800    0.4780       300
#
# ===
# fever-climatefever-bert-base-uncased.dev
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.4815    0.5804    0.5263       112
#         REFUTES     0.3548    0.1719    0.2316        64
#        SUPPORTS     0.5672    0.6129    0.5891       124
#
#        accuracy                         0.5067       300
#       macro avg     0.4678    0.4550    0.4490       300
#    weighted avg     0.4899    0.5067    0.4894       300
#
# ===
# climatefeverpure-xlnet-base-cased.dev
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.5316    0.3750    0.4398       112
#         REFUTES     0.3077    0.1250    0.1778        64
#        SUPPORTS     0.4872    0.7661    0.5956       124
#
#        accuracy                         0.4833       300
#       macro avg     0.4422    0.4220    0.4044       300
#    weighted avg     0.4655    0.4833    0.4483       300
#
# ===
# fever-xlnet-base-cased.dev
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.6818    0.1339    0.2239       112
#         REFUTES     0.3676    0.3906    0.3788        64
#        SUPPORTS     0.5095    0.8629    0.6407       124
#
#        accuracy                         0.4900       300
#       macro avg     0.5197    0.4625    0.4145       300
#    weighted avg     0.5436    0.4900    0.4292       300
#
# ===
# climatefever-xlnet-base-cased.dev
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.5232    0.7054    0.6008       112
#         REFUTES     0.3750    0.0469    0.0833        64
#        SUPPORTS     0.5816    0.6613    0.6189       124
#
#        accuracy                         0.5467       300
#       macro avg     0.4932    0.4712    0.4343       300
#    weighted avg     0.5157    0.5467    0.4979       300
#
# ===
# climatefeverpure-bert-base-uncased.dev
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.6429    0.1607    0.2571       112
#         REFUTES     0.2800    0.1094    0.1573        64
#        SUPPORTS     0.4332    0.8629    0.5768       124
#
#        accuracy                         0.4400       300
#       macro avg     0.4520    0.3777    0.3304       300
#    weighted avg     0.4788    0.4400    0.3680       300
#
# ===
# fever-climatefeverpure-xlnet-base-cased.dev
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.6452    0.3571    0.4598       112
#         REFUTES     0.4783    0.3438    0.4000        64
#        SUPPORTS     0.5312    0.8226    0.6456       124
#
#        accuracy                         0.5467       300
#       macro avg     0.5516    0.5078    0.5018       300
#    weighted avg     0.5625    0.5467    0.5238       300
#
# ===
# fever-bert-base-uncased.dev
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.8462    0.0982    0.1760       112
#         REFUTES     0.3077    0.5625    0.3978        64
#        SUPPORTS     0.5353    0.7339    0.6190       124
#
#        accuracy                         0.4600       300
#       macro avg     0.5630    0.4649    0.3976       300
#    weighted avg     0.6028    0.4600    0.4064       300
#
# ===
# climatefever-bert-base-uncased.dev
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.5098    0.4643    0.4860       112
#         REFUTES     0.2222    0.0625    0.0976        64
#        SUPPORTS     0.5000    0.7258    0.5921       124
#
#        accuracy                         0.4867       300
#       macro avg     0.4107    0.4175    0.3919       300
#    weighted avg     0.4444    0.4867    0.4470       300
#
# ===
# fever-climatefever-xlnet-base-cased.dev
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.5333    0.5714    0.5517       112
#         REFUTES     0.4524    0.2969    0.3585        64
#        SUPPORTS     0.5797    0.6452    0.6107       124
#
#        accuracy                         0.5433       300
#       macro avg     0.5218    0.5045    0.5070       300
#    weighted avg     0.5352    0.5433    0.5349       300
#
# ===
