# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # Init

# %%
import json
import sys
import re
import pickle as pkl
from pathlib import Path
from functools import partial
from collections import defaultdict, namedtuple
sys.path.append("../src")

import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
from joblib import Parallel, delayed
from tqdm import tqdm
from sklearn.metrics import classification_report, precision_recall_fscore_support, accuracy_score

import constants
from scoring import scorer
from gen.util import read_data, write_jsonl
from rte import aggregate

# %%
data_sent_micro_p = Path("/users/k21190024/study/fact-check-transfer-learning/scratch/dumps/bert-data-sent-evidence")

pred_p = Path("/users/k21190024/study/fact-check-transfer-learning/scratch/thesis/predictions")
result_p = Path("/users/k21190024/study/fact-check-transfer-learning/scratch/thesis/results/metrics")

fever_actual_p = Path("/users/k21190024/study/fact-check-transfer-learning/scratch/dumps/fever-nei-sampled")
cfever_actual_p = Path("/users/k21190024/study/fact-check-transfer-learning/scratch/dumps/climatefever-neg-sampled")
cfeverpure_actual_p = Path("/users/k21190024/study/fact-check-transfer-learning/scratch/dumps/climatefeverpure-neg-sampled")
sf_actual_p = Path("/users/k21190024/study/fact-check-transfer-learning/scratch/dumps/scifact-nei-sampled/all.n5.nei.jsonl")

actual_pls = (
    list(fever_actual_p.glob("*.n5.nei.jsonl")) 
    + list(cfever_actual_p.glob("*.n5.nei.jsonl")) 
    + list(cfeverpure_actual_p.glob("*.n5.nei.jsonl")) 
    + [sf_actual_p]
)
actual_pls = [p for p in actual_pls if "train" not in p.stem]

# %% [markdown]
# # Concatenate Evidences

# %%
concat_evi_res = {"fever": defaultdict(list), "climatefeverpure": defaultdict(list), "scifact": defaultdict(list)}

for actual_dp in tqdm(actual_pls):
    dataset = actual_dp.parent.stem.split("-")[0]
    split = actual_dp.stem.split(".")[0]
    actual_data = read_data(actual_dp)
    if dataset == "climatefeverpure":
        score_obj = scorer.ClimateFEVERScorer
    elif dataset == "climatefever":
        continue
    else:
        score_obj = scorer.FEVERScorer
        
    for pp in pred_p.joinpath("doc", dataset).glob(f"*.{split}.jsonl"):
        preds = read_data(pp)
        concat_evi_res[dataset][split].append(score_obj(actual_data=actual_data, prediction_data=preds, score_name=pp.stem, oracle_rte=False, oracle_ir=True, max_evidence=None))
# Out:
# 100%|██████████| 7/7 [00:09<00:00,  1.38s/it]

# %%
with result_p.joinpath("concatenate_evidences_metrics.pkl").open("wb") as fn:
    pkl.dump(concat_evi_res, fn)

# %%
for score in concat_evi_res["fever"]["dev"]:
    print(score._score_name)
    print(score.classification_report)
    print("===")
# Out:
# fever-climatefeverpure-bert-base-uncased.dev
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.9967    0.9967    0.9967      3333
#         REFUTES     0.9565    0.8983    0.9265      3333
#        SUPPORTS     0.9038    0.9589    0.9306      3333
#
#        accuracy                         0.9513      9999
#       macro avg     0.9524    0.9513    0.9513      9999
#    weighted avg     0.9524    0.9513    0.9513      9999
#
# ===
# fever-da.dev
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.7925    0.8446    0.8177      3333
#         REFUTES     0.9042    0.3909    0.5459      3333
#        SUPPORTS     0.5733    0.8611    0.6883      3333
#
#        accuracy                         0.6989      9999
#       macro avg     0.7567    0.6989    0.6840      9999
#    weighted avg     0.7567    0.6989    0.6840      9999
#
# ===
# climatefeverpure-xlnet-base-cased.dev
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.1028    0.0099    0.0181      3333
#         REFUTES     0.7144    0.3729    0.4900      3333
#        SUPPORTS     0.3913    0.9319    0.5511      3333
#
#        accuracy                         0.4382      9999
#       macro avg     0.4028    0.4382    0.3531      9999
#    weighted avg     0.4028    0.4382    0.3531      9999
#
# ===
# fever-xlnet-base-cased.dev
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.9985    0.9919    0.9952      3333
#         REFUTES     0.9527    0.9121    0.9319      3333
#        SUPPORTS     0.9122    0.9571    0.9341      3333
#
#        accuracy                         0.9537      9999
#       macro avg     0.9545    0.9537    0.9537      9999
#    weighted avg     0.9545    0.9537    0.9537      9999
#
# ===
# fever-climatefeverpure-da.dev
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.8774    0.8761    0.8767      3333
#         REFUTES     0.8961    0.4815    0.6265      3333
#        SUPPORTS     0.6125    0.8968    0.7279      3333
#
#        accuracy                         0.7515      9999
#       macro avg     0.7954    0.7515    0.7437      9999
#    weighted avg     0.7954    0.7515    0.7437      9999
#
# ===
# climatefeverpure-bert-base-uncased.dev
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.8616    0.5008    0.6334      3333
#         REFUTES     0.7338    0.0984    0.1735      3333
#        SUPPORTS     0.4239    0.9685    0.5897      3333
#
#        accuracy                         0.5226      9999
#       macro avg     0.6731    0.5226    0.4655      9999
#    weighted avg     0.6731    0.5226    0.4655      9999
#
# ===
# fever-climatefeverpure-xlnet-base-cased.dev
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.9985    0.9913    0.9949      3333
#         REFUTES     0.9533    0.9070    0.9296      3333
#        SUPPORTS     0.9074    0.9580    0.9320      3333
#
#        accuracy                         0.9521      9999
#       macro avg     0.9531    0.9521    0.9522      9999
#    weighted avg     0.9531    0.9521    0.9522      9999
#
# ===
# fever-bert-base-uncased.dev
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.9967    0.9964    0.9965      3333
#         REFUTES     0.9574    0.9031    0.9294      3333
#        SUPPORTS     0.9077    0.9595    0.9329      3333
#
#        accuracy                         0.9530      9999
#       macro avg     0.9539    0.9530    0.9530      9999
#    weighted avg     0.9539    0.9530    0.9530      9999
#
# ===
# climatefeverpure-da.dev
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.3773    0.1296    0.1929      3333
#         REFUTES     0.3061    0.2460    0.2728      3333
#        SUPPORTS     0.3351    0.6208    0.4352      3333
#
#        accuracy                         0.3321      9999
#       macro avg     0.3395    0.3321    0.3003      9999
#    weighted avg     0.3395    0.3321    0.3003      9999
#
# ===

# %%
for score in concat_evi_res["climatefeverpure"]["dev"]:
    print(score._score_name)
    print(score.classification_report)
    print("===")
# Out:
# fever-climatefeverpure-bert-base-uncased.dev
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.8391    0.7684    0.8022        95
#         REFUTES     0.4776    0.6275    0.5424        51
#        SUPPORTS     0.7742    0.7273    0.7500       132
#
#        accuracy                         0.7230       278
#       macro avg     0.6970    0.7077    0.6982       278
#    weighted avg     0.7420    0.7230    0.7297       278
#
# ===
# fever-da.dev
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.4082    0.2105    0.2778        95
#         REFUTES     0.4000    0.3137    0.3516        51
#        SUPPORTS     0.5132    0.7348    0.6044       132
#
#        accuracy                         0.4784       278
#       macro avg     0.4405    0.4197    0.4113       278
#    weighted avg     0.4566    0.4784    0.4464       278
#
# ===
# climatefeverpure-xlnet-base-cased.dev
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.8750    0.8842    0.8796        95
#         REFUTES     0.6531    0.6275    0.6400        51
#        SUPPORTS     0.8045    0.8106    0.8075       132
#
#        accuracy                         0.8022       278
#       macro avg     0.7775    0.7741    0.7757       278
#    weighted avg     0.8008    0.8022    0.8014       278
#
# ===
# fever-xlnet-base-cased.dev
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.7143    0.2105    0.3252        95
#         REFUTES     0.3750    0.7059    0.4898        51
#        SUPPORTS     0.6429    0.7500    0.6923       132
#
#        accuracy                         0.5576       278
#       macro avg     0.5774    0.5555    0.5024       278
#    weighted avg     0.6181    0.5576    0.5297       278
#
# ===
# fever-climatefeverpure-da.dev
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.6260    0.8632    0.7257        95
#         REFUTES     0.4545    0.1961    0.2740        51
#        SUPPORTS     0.7200    0.6818    0.7004       132
#
#        accuracy                         0.6547       278
#       macro avg     0.6002    0.5804    0.5667       278
#    weighted avg     0.6392    0.6547    0.6308       278
#
# ===
# climatefeverpure-bert-base-uncased.dev
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.8632    0.8632    0.8632        95
#         REFUTES     0.5526    0.4118    0.4719        51
#        SUPPORTS     0.7517    0.8258    0.7870       132
#
#        accuracy                         0.7626       278
#       macro avg     0.7225    0.7002    0.7074       278
#    weighted avg     0.7533    0.7626    0.7552       278
#
# ===
# fever-climatefeverpure-xlnet-base-cased.dev
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.8861    0.7368    0.8046        95
#         REFUTES     0.5806    0.7059    0.6372        51
#        SUPPORTS     0.7810    0.8106    0.7955       132
#
#        accuracy                         0.7662       278
#       macro avg     0.7492    0.7511    0.7458       278
#    weighted avg     0.7802    0.7662    0.7696       278
#
# ===
# fever-bert-base-uncased.dev
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.5500    0.1158    0.1913        95
#         REFUTES     0.2957    0.6667    0.4096        51
#        SUPPORTS     0.6294    0.6818    0.6545       132
#
#        accuracy                         0.4856       278
#       macro avg     0.4917    0.4881    0.4185       278
#    weighted avg     0.5410    0.4856    0.4513       278
#
# ===
# climatefeverpure-da.dev
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.7789    0.7789    0.7789        95
#         REFUTES     0.5357    0.2941    0.3797        51
#        SUPPORTS     0.6710    0.7879    0.7247       132
#
#        accuracy                         0.6942       278
#       macro avg     0.6619    0.6203    0.6278       278
#    weighted avg     0.6831    0.6942    0.6800       278
#
# ===

# %%
for score in concat_evi_res["scifact"]["all"]:
    print(score._score_name)
    print(score.classification_report)
    print("===")
# Out:
# climatefeverpure-bert-base-uncased.all
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.5476    0.1659    0.2546       416
#         REFUTES     0.3898    0.0970    0.1554       237
#        SUPPORTS     0.4394    0.8904    0.5884       456
#
#        accuracy                         0.4491      1109
#       macro avg     0.4589    0.3844    0.3328      1109
#    weighted avg     0.4694    0.4491    0.3707      1109
#
# ===
# fever-climatefeverpure-da.all
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.4762    0.0481    0.0873       416
#         REFUTES     0.3723    0.1477    0.2115       237
#        SUPPORTS     0.4337    0.9254    0.5906       456
#
#        accuracy                         0.4301      1109
#       macro avg     0.4274    0.3737    0.2965      1109
#    weighted avg     0.4365    0.4301    0.3208      1109
#
# ===
# fever-bert-base-uncased.all
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.8985    1.0000    0.9465       416
#         REFUTES     0.6302    0.5105    0.5641       237
#        SUPPORTS     0.7907    0.7873    0.7890       456
#
#        accuracy                         0.8079      1109
#       macro avg     0.7731    0.7659    0.7665      1109
#    weighted avg     0.7969    0.8079    0.8000      1109
#
# ===
# climatefeverpure-da.all
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.2465    0.1683    0.2000       416
#         REFUTES     0.2074    0.1646    0.1835       237
#        SUPPORTS     0.3846    0.5373    0.4483       456
#
#        accuracy                         0.3192      1109
#       macro avg     0.2795    0.2900    0.2773      1109
#    weighted avg     0.2949    0.3192    0.2986      1109
#
# ===
# fever-climatefeverpure-bert-base-uncased.all
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.8469    0.9976    0.9161       416
#         REFUTES     0.7029    0.4093    0.5173       237
#        SUPPORTS     0.7879    0.8311    0.8090       456
#
#        accuracy                         0.8034      1109
#       macro avg     0.7793    0.7460    0.7475      1109
#    weighted avg     0.7919    0.8034    0.7868      1109
#
# ===
# fever-da.all
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.7068    0.2260    0.3424       416
#         REFUTES     0.3944    0.1181    0.1818       237
#        SUPPORTS     0.4619    0.9167    0.6143       456
#
#        accuracy                         0.4869      1109
#       macro avg     0.5210    0.4203    0.3795      1109
#    weighted avg     0.5393    0.4869    0.4199      1109
#
# ===
# fever-xlnet-base-cased.all
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.9303    0.9952    0.9617       416
#         REFUTES     0.7400    0.4684    0.5736       237
#        SUPPORTS     0.7802    0.8794    0.8268       456
#
#        accuracy                         0.8350      1109
#       macro avg     0.8168    0.7810    0.7874      1109
#    weighted avg     0.8279    0.8350    0.8233      1109
#
# ===
# fever-climatefeverpure-xlnet-base-cased.all
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.9020    0.9952    0.9463       416
#         REFUTES     0.7521    0.3713    0.4972       237
#        SUPPORTS     0.7617    0.8904    0.8210       456
#
#        accuracy                         0.8188      1109
#       macro avg     0.8053    0.7523    0.7548      1109
#    weighted avg     0.8123    0.8188    0.7988      1109
#
# ===
# climatefeverpure-xlnet-base-cased.all
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.1786    0.0240    0.0424       416
#         REFUTES     0.3889    0.3840    0.3864       237
#        SUPPORTS     0.4689    0.8421    0.6024       456
#
#        accuracy                         0.4373      1109
#       macro avg     0.3454    0.4167    0.3437      1109
#    weighted avg     0.3429    0.4373    0.3461      1109
#
# ===

# %% [markdown]
# # Sentence

# %%
sent_pls = list(data_sent_micro_p.glob("*.dev*")) + list(data_sent_micro_p.glob("*.test*"))
sent_pls = [p for p in sent_pls if "fever-climatefever" not in p.stem]

# %% [markdown]
# ## Micro verdict

# %%
sent_micro_res = {
    "fever": defaultdict(list), 
    "climatefeverpure": defaultdict(list), 
    "scifact": defaultdict(list),
    "climatefever": defaultdict(list)
}
# sscore = namedtuple("SentenceScorer", ["score_name", "classification_report", "rte_metrics"], module=scorer)

for actual_dp in tqdm(sent_pls):
    dataset = actual_dp.stem.split(".")[0]
    split = actual_dp.stem.split(".")[1]
    actual_data = read_data(actual_dp)
    
    for pp in pred_p.joinpath("sent", dataset).glob(f"*.{split}.jsonl"):
        preds = read_data(pp)
        assert len(actual_data) == len(preds), f"{actual_dp} ({len(actual_data)}) != {pp} ({len(preds)})"
        actual_labels = [constants.ID2LABEL[i["labels"]] for i in actual_data]
        predicted_labels = [i["predicted_label"] for i in preds]

        mi_p, mi_r, mi_f, _ = precision_recall_fscore_support(y_true=actual_labels, y_pred=predicted_labels, average="micro", beta=1.0)
        ma_p, ma_r, ma_f, _ = precision_recall_fscore_support(y_true=actual_labels, y_pred=predicted_labels, average="macro", beta=1.0)
        rte_metrics = {
            "accuracy": accuracy_score(y_true=actual_labels, y_pred=predicted_labels),
            "micro_precision": mi_p,
            "micro_recall": mi_r,
            "micro_f1": mi_f,
            "macro_precision": ma_p,
            "macro_recall": ma_r,
            "macro_f1": ma_f,

        }
        
        sent_micro_res[dataset][split].append(scorer.SentenceMicroScorer(
            pp.stem, 
            classification_report(y_true=actual_labels, y_pred=predicted_labels, digits=4),
            classification_report(y_true=actual_labels, y_pred=predicted_labels, output_dict=True),
            rte_metrics
        ))
# Out:
# 100%|██████████| 7/7 [00:13<00:00,  1.88s/it]

# %%
with result_p.joinpath("sent_micro_verdict_metrics.pkl").open("wb") as fn:
    pkl.dump(sent_micro_res, fn)

# %%
for score in sent_micro_res["fever"]["dev"]:
    print(score._score_name)
    print(score.classification_report)
    print("===")
# Out:
# fever-climatefeverpure-bert-base-uncased.dev
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.9743    0.9853    0.9798      6666
#         REFUTES     0.9519    0.9036    0.9272      4888
#        SUPPORTS     0.9156    0.9501    0.9325      4588
#
#        accuracy                         0.9506     16142
#       macro avg     0.9473    0.9463    0.9465     16142
#    weighted avg     0.9508    0.9506    0.9504     16142
#
# ===
# fever-climatefever-bert-base-uncased.dev
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.9778    0.9790    0.9784      6666
#         REFUTES     0.9482    0.9059    0.9266      4888
#        SUPPORTS     0.9123    0.9540    0.9327      4588
#
#        accuracy                         0.9498     16142
#       macro avg     0.9461    0.9463    0.9459     16142
#    weighted avg     0.9502    0.9498    0.9497     16142
#
# ===
# climatefeverpure-xlnet-base-cased.dev
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.5780    0.9070    0.7060      6666
#         REFUTES     0.8906    0.1199    0.2113      4888
#        SUPPORTS     0.5584    0.6114    0.5837      4588
#
#        accuracy                         0.5846     16142
#       macro avg     0.6757    0.5461    0.5003     16142
#    weighted avg     0.6671    0.5846    0.5215     16142
#
# ===
# fever-xlnet-base-cased.dev
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.9810    0.9748    0.9779      6666
#         REFUTES     0.9417    0.9190    0.9302      4888
#        SUPPORTS     0.9200    0.9520    0.9357      4588
#
#        accuracy                         0.9514     16142
#       macro avg     0.9476    0.9486    0.9479     16142
#    weighted avg     0.9517    0.9514    0.9515     16142
#
# ===
# climatefever-xlnet-base-cased.dev
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.4854    0.9931    0.6521      6666
#         REFUTES     0.9511    0.1035    0.1867      4888
#        SUPPORTS     0.7152    0.3075    0.4301      4588
#
#        accuracy                         0.5289     16142
#       macro avg     0.7172    0.4681    0.4230     16142
#    weighted avg     0.6917    0.5289    0.4481     16142
#
# ===
# climatefeverpure-bert-base-uncased.dev
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.6547    0.9086    0.7611      6666
#         REFUTES     0.9265    0.1804    0.3021      4888
#        SUPPORTS     0.5600    0.7249    0.6319      4588
#
#        accuracy                         0.6359     16142
#       macro avg     0.7137    0.6047    0.5650     16142
#    weighted avg     0.7101    0.6359    0.5854     16142
#
# ===
# fever-climatefeverpure-xlnet-base-cased.dev
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.9810    0.9740    0.9775      6666
#         REFUTES     0.9445    0.9114    0.9276      4888
#        SUPPORTS     0.9139    0.9573    0.9351      4588
#
#        accuracy                         0.9503     16142
#       macro avg     0.9464    0.9476    0.9467     16142
#    weighted avg     0.9508    0.9503    0.9503     16142
#
# ===
# fever-bert-base-uncased.dev
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.9762    0.9826    0.9794      6666
#         REFUTES     0.9488    0.9094    0.9287      4888
#        SUPPORTS     0.9197    0.9516    0.9354      4588
#
#        accuracy                         0.9516     16142
#       macro avg     0.9482    0.9479    0.9478     16142
#    weighted avg     0.9518    0.9516    0.9515     16142
#
# ===
# climatefever-bert-base-uncased.dev
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.5898    0.9877    0.7385      6666
#         REFUTES     0.9440    0.1000    0.1809      4888
#        SUPPORTS     0.6464    0.6284    0.6373      4588
#
#        accuracy                         0.6168     16142
#       macro avg     0.7267    0.5720    0.5189     16142
#    weighted avg     0.7131    0.6168    0.5409     16142
#
# ===
# fever-climatefever-xlnet-base-cased.dev
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.9800    0.9781    0.9791      6666
#         REFUTES     0.9463    0.9124    0.9291      4888
#        SUPPORTS     0.9183    0.9560    0.9368      4588
#
#        accuracy                         0.9519     16142
#       macro avg     0.9482    0.9488    0.9483     16142
#    weighted avg     0.9523    0.9519    0.9519     16142
#
# ===

# %%
for score in sent_micro_res["climatefeverpure"]["dev"]:
    print(score._score_name)
    print(score.classification_report)
    print("===")
# Out:
# fever-climatefeverpure-bert-base-uncased.dev
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.7430    0.6695    0.7043       475
#         REFUTES     0.4076    0.4848    0.4429       132
#        SUPPORTS     0.6404    0.6844    0.6616       320
#
#        accuracy                         0.6483       927
#       macro avg     0.5970    0.6129    0.6030       927
#    weighted avg     0.6598    0.6483    0.6524       927
#
# ===
# fever-climatefever-bert-base-uncased.dev
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.6453    0.9116    0.7557       475
#         REFUTES     0.5301    0.3333    0.4093       132
#        SUPPORTS     0.8150    0.4406    0.5720       320
#
#        accuracy                         0.6667       927
#       macro avg     0.6635    0.5618    0.5790       927
#    weighted avg     0.6875    0.6667    0.6430       927
#
# ===
# climatefeverpure-xlnet-base-cased.dev
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.7541    0.6779    0.7140       475
#         REFUTES     0.7000    0.5303    0.6034       132
#        SUPPORTS     0.5900    0.7375    0.6556       320
#
#        accuracy                         0.6775       927
#       macro avg     0.6814    0.6486    0.6577       927
#    weighted avg     0.6897    0.6775    0.6781       927
#
# ===
# fever-xlnet-base-cased.dev
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.6850    0.3663    0.4774       475
#         REFUTES     0.3040    0.6288    0.4099       132
#        SUPPORTS     0.4950    0.6188    0.5500       320
#
#        accuracy                         0.4908       927
#       macro avg     0.4947    0.5380    0.4791       927
#    weighted avg     0.5652    0.4908    0.4928       927
#
# ===
# climatefever-xlnet-base-cased.dev
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.6351    0.8463    0.7256       475
#         REFUTES     0.8246    0.3561    0.4974       132
#        SUPPORTS     0.6624    0.4906    0.5637       320
#
#        accuracy                         0.6537       927
#       macro avg     0.7074    0.5643    0.5956       927
#    weighted avg     0.6715    0.6537    0.6372       927
#
# ===
# climatefeverpure-bert-base-uncased.dev
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.7633    0.6042    0.6745       475
#         REFUTES     0.5172    0.4545    0.4839       132
#        SUPPORTS     0.5770    0.7844    0.6649       320
#
#        accuracy                         0.6451       927
#       macro avg     0.6192    0.6144    0.6078       927
#    weighted avg     0.6640    0.6451    0.6440       927
#
# ===
# fever-climatefeverpure-xlnet-base-cased.dev
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.7622    0.5600    0.6456       475
#         REFUTES     0.6164    0.6818    0.6475       132
#        SUPPORTS     0.5579    0.7531    0.6410       320
#
#        accuracy                         0.6440       927
#       macro avg     0.6455    0.6650    0.6447       927
#    weighted avg     0.6709    0.6440    0.6443       927
#
# ===
# fever-bert-base-uncased.dev
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.8394    0.2421    0.3758       475
#         REFUTES     0.2290    0.6818    0.3429       132
#        SUPPORTS     0.5466    0.6781    0.6053       320
#
#        accuracy                         0.4552       927
#       macro avg     0.5383    0.5340    0.4413       927
#    weighted avg     0.6514    0.4552    0.4503       927
#
# ===
# climatefever-bert-base-uncased.dev
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.6472    0.9347    0.7649       475
#         REFUTES     0.7895    0.3409    0.4762       132
#        SUPPORTS     0.7772    0.4469    0.5675       320
#
#        accuracy                         0.6818       927
#       macro avg     0.7380    0.5742    0.6028       927
#    weighted avg     0.7123    0.6818    0.6556       927
#
# ===
# fever-climatefever-xlnet-base-cased.dev
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.5989    0.9305    0.7288       475
#         REFUTES     0.7091    0.2955    0.4171       132
#        SUPPORTS     0.7761    0.3250    0.4581       320
#
#        accuracy                         0.6311       927
#       macro avg     0.6947    0.5170    0.5347       927
#    weighted avg     0.6758    0.6311    0.5910       927
#
# ===

# %%
for score in sent_micro_res["climatefever"]["dev"]:
    print(score._score_name)
    print(score.classification_report)
    print("===")
# Out:
# fever-climatefeverpure-bert-base-uncased.dev
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.8246    0.5512    0.6607       938
#         REFUTES     0.2832    0.4848    0.3575       132
#        SUPPORTS     0.4078    0.6844    0.5111       320
#
#        accuracy                         0.5755      1390
#       macro avg     0.5052    0.5735    0.5098      1390
#    weighted avg     0.6772    0.5755    0.5975      1390
#
# ===
# fever-climatefever-bert-base-uncased.dev
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.7674    0.8369    0.8006       938
#         REFUTES     0.4151    0.3333    0.3697       132
#        SUPPORTS     0.5402    0.4406    0.4854       320
#
#        accuracy                         0.6978      1390
#       macro avg     0.5742    0.5369    0.5519      1390
#    weighted avg     0.6816    0.6978    0.6871      1390
#
# ===
# climatefeverpure-xlnet-base-cased.dev
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.8273    0.5362    0.6507       938
#         REFUTES     0.4094    0.5303    0.4620       132
#        SUPPORTS     0.3863    0.7375    0.5070       320
#
#        accuracy                         0.5820      1390
#       macro avg     0.5410    0.6014    0.5399      1390
#    weighted avg     0.6861    0.5820    0.5997      1390
#
# ===
# fever-xlnet-base-cased.dev
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.7861    0.3134    0.4482       938
#         REFUTES     0.2060    0.6288    0.3103       132
#        SUPPORTS     0.3230    0.6188    0.4244       320
#
#        accuracy                         0.4137      1390
#       macro avg     0.4384    0.5203    0.3943      1390
#    weighted avg     0.6244    0.4137    0.4296      1390
#
# ===
# climatefever-xlnet-base-cased.dev
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.7548    0.7580    0.7564       938
#         REFUTES     0.6267    0.3561    0.4541       132
#        SUPPORTS     0.4209    0.4906    0.4531       320
#
#        accuracy                         0.6583      1390
#       macro avg     0.6008    0.5349    0.5545      1390
#    weighted avg     0.6658    0.6583    0.6579      1390
#
# ===
# climatefeverpure-bert-base-uncased.dev
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.8311    0.4670    0.5980       938
#         REFUTES     0.3509    0.4545    0.3960       132
#        SUPPORTS     0.3627    0.7844    0.4960       320
#
#        accuracy                         0.5388      1390
#       macro avg     0.5149    0.5686    0.4967      1390
#    weighted avg     0.6777    0.5388    0.5553      1390
#
# ===
# fever-climatefeverpure-xlnet-base-cased.dev
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.8376    0.4563    0.5908       938
#         REFUTES     0.4110    0.6818    0.5128       132
#        SUPPORTS     0.3652    0.7531    0.4918       320
#
#        accuracy                         0.5460      1390
#       macro avg     0.5379    0.6304    0.5318      1390
#    weighted avg     0.6883    0.5460    0.5606      1390
#
# ===
# fever-bert-base-uncased.dev
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.8854    0.1812    0.3009       938
#         REFUTES     0.1562    0.6818    0.2542       132
#        SUPPORTS     0.3489    0.6781    0.4607       320
#
#        accuracy                         0.3432      1390
#       macro avg     0.4635    0.5137    0.3386      1390
#    weighted avg     0.6927    0.3432    0.3333      1390
#
# ===
# climatefever-bert-base-uncased.dev
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.7682    0.8550    0.8093       938
#         REFUTES     0.6000    0.3409    0.4348       132
#        SUPPORTS     0.5277    0.4469    0.4839       320
#
#        accuracy                         0.7122      1390
#       macro avg     0.6320    0.5476    0.5760      1390
#    weighted avg     0.6969    0.7122    0.6988      1390
#
# ===
# fever-climatefever-xlnet-base-cased.dev
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.7404    0.8998    0.8123       938
#         REFUTES     0.5909    0.2955    0.3939       132
#        SUPPORTS     0.5652    0.3250    0.4127       320
#
#        accuracy                         0.7101      1390
#       macro avg     0.6322    0.5067    0.5397      1390
#    weighted avg     0.6858    0.7101    0.6806      1390
#
# ===

# %%
for score in sent_micro_res["scifact"]["all"]:
    print(score._score_name)
    print(score.classification_report)
    print("===")
# Out:
# fever-climatefever-xlnet-base-cased.all
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.6370    0.9976    0.7775       832
#         REFUTES     0.7644    0.3475    0.4778       495
#        SUPPORTS     0.8058    0.6250    0.7040       896
#
#        accuracy                         0.7027      2223
#       macro avg     0.7357    0.6567    0.6531      2223
#    weighted avg     0.7334    0.7027    0.6811      2223
#
# ===
# climatefeverpure-bert-base-uncased.all
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.8639    0.6334    0.7309       832
#         REFUTES     0.5395    0.1657    0.2535       495
#        SUPPORTS     0.5414    0.8828    0.6712       896
#
#        accuracy                         0.6298      2223
#       macro avg     0.6483    0.5606    0.5519      2223
#    weighted avg     0.6617    0.6298    0.6005      2223
#
# ===
# climatefever-xlnet-base-cased.all
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.5546    0.9591    0.7028       832
#         REFUTES     0.6200    0.0626    0.1138       495
#        SUPPORTS     0.7153    0.5859    0.6442       896
#
#        accuracy                         0.6091      2223
#       macro avg     0.6299    0.5359    0.4869      2223
#    weighted avg     0.6339    0.6091    0.5480      2223
#
# ===
# fever-bert-base-uncased.all
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.8379    0.9940    0.9093       832
#         REFUTES     0.6582    0.5212    0.5817       495
#        SUPPORTS     0.7927    0.7467    0.7690       896
#
#        accuracy                         0.7890      2223
#       macro avg     0.7629    0.7540    0.7533      2223
#    weighted avg     0.7796    0.7890    0.7798      2223
#
# ===
# fever-climatefeverpure-bert-base-uncased.all
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.7584    1.0000    0.8626       832
#         REFUTES     0.6500    0.4465    0.5293       495
#        SUPPORTS     0.7850    0.6886    0.7337       896
#
#        accuracy                         0.7512      2223
#       macro avg     0.7311    0.7117    0.7085      2223
#    weighted avg     0.7450    0.7512    0.7364      2223
#
# ===
# fever-climatefever-bert-base-uncased.all
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.6661    1.0000    0.7996       832
#         REFUTES     0.6419    0.3838    0.4804       495
#        SUPPORTS     0.8097    0.6127    0.6976       896
#
#        accuracy                         0.7067      2223
#       macro avg     0.7059    0.6655    0.6592      2223
#    weighted avg     0.7186    0.7067    0.6874      2223
#
# ===
# climatefever-bert-base-uncased.all
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.6757    0.9940    0.8045       832
#         REFUTES     0.5862    0.1030    0.1753       495
#        SUPPORTS     0.7116    0.7243    0.7179       896
#
#        accuracy                         0.6869      2223
#       macro avg     0.6578    0.6071    0.5659      2223
#    weighted avg     0.6702    0.6869    0.6295      2223
#
# ===
# fever-xlnet-base-cased.all
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.7518    0.9904    0.8548       832
#         REFUTES     0.7267    0.4566    0.5608       495
#        SUPPORTS     0.8027    0.7310    0.7652       896
#
#        accuracy                         0.7670      2223
#       macro avg     0.7604    0.7260    0.7269      2223
#    weighted avg     0.7667    0.7670    0.7532      2223
#
# ===
# fever-climatefeverpure-xlnet-base-cased.all
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.7376    0.9868    0.8442       832
#         REFUTES     0.7234    0.4121    0.5251       495
#        SUPPORTS     0.7754    0.7165    0.7448       896
#
#        accuracy                         0.7499      2223
#       macro avg     0.7455    0.7051    0.7047      2223
#    weighted avg     0.7497    0.7499    0.7331      2223
#
# ===
# climatefeverpure-xlnet-base-cased.all
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.6562    0.7500    0.6999       832
#         REFUTES     0.6391    0.2182    0.3253       495
#        SUPPORTS     0.6002    0.7388    0.6623       896
#
#        accuracy                         0.6271      2223
#       macro avg     0.6318    0.5690    0.5625      2223
#    weighted avg     0.6298    0.6271    0.6014      2223
#
# ===

# %% [markdown]
# ## Macro verdict

# %% [markdown]
# ### Majority

# %%
majority_agg_res = {
    "fever": defaultdict(list), 
    "climatefeverpure": defaultdict(list), 
    "scifact": defaultdict(list),
    "climatefever": defaultdict(list)
}

for actual_dp in tqdm(actual_pls):
    dataset = actual_dp.parent.stem.split("-")[0]
    split = actual_dp.stem.split(".")[0]
    actual_data = read_data(actual_dp)
    if "climatefever" in dataset:
        score_obj = scorer.ClimateFEVERScorer
    else:
        score_obj = scorer.FEVERScorer
        
    for pp in pred_p.joinpath("sent", dataset).glob(f"*.{split}.jsonl"):
        preds = read_data(pp)
        sent_actual_data = read_data(data_sent_micro_p.joinpath("scifact.all.test.n5.jsonl" if dataset == "scifact" else f"{dataset}.{split}.n5.jsonl"))
        
        # aggregate
        df_agg = pd.DataFrame(sent_actual_data).merge(pd.DataFrame(preds), on="claim_id", how="left")
        df_agg["predicted_label"] = df_agg["predicted_label"].map(constants.LABEL2ID)
        df_agg = df_agg.groupby("claim_id", sort=False).agg({"predicted_label": aggregate.agg_predict})
        df_agg["predicted_label"] = df_agg["predicted_label"].map(constants.ID2LABEL)
        df_agg = df_agg.reset_index()
        df_agg = df_agg.to_dict("records")
        
        majority_agg_res[dataset][split].append(score_obj(actual_data=actual_data, prediction_data=df_agg, oracle_rte=False, oracle_ir=True, max_evidence=None, score_name=pp.stem))
# Out:
# 100%|██████████| 7/7 [00:19<00:00,  2.81s/it]

# %%
with result_p.joinpath("sent_macro_verdict_majority_metrics.pkl").open("wb") as fn:
    pkl.dump(majority_agg_res, fn)

# %%
for score in majority_agg_res["fever"]["dev"]:
    print(score._score_name)
    print(score.classification_report)
    print("===")
# Out:
# fever-climatefeverpure-bert-base-uncased.dev
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.9828    0.9775    0.9801      3333
#         REFUTES     0.9438    0.9064    0.9247      3333
#        SUPPORTS     0.9076    0.9484    0.9275      3333
#
#        accuracy                         0.9441      9999
#       macro avg     0.9447    0.9441    0.9441      9999
#    weighted avg     0.9447    0.9441    0.9441      9999
#
# ===
# fever-climatefever-bert-base-uncased.dev
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.9814    0.9661    0.9737      3333
#         REFUTES     0.9387    0.9052    0.9216      3333
#        SUPPORTS     0.9064    0.9529    0.9291      3333
#
#        accuracy                         0.9414      9999
#       macro avg     0.9422    0.9414    0.9415      9999
#    weighted avg     0.9422    0.9414    0.9415      9999
#
# ===
# climatefeverpure-xlnet-base-cased.dev
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.5453    0.8719    0.6710      3333
#         REFUTES     0.8946    0.1350    0.2346      3333
#        SUPPORTS     0.5553    0.6943    0.6171      3333
#
#        accuracy                         0.5671      9999
#       macro avg     0.6651    0.5671    0.5076      9999
#    weighted avg     0.6651    0.5671    0.5076      9999
#
# ===
# fever-xlnet-base-cased.dev
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.9849    0.9589    0.9717      3333
#         REFUTES     0.9298    0.9175    0.9236      3333
#        SUPPORTS     0.9120    0.9481    0.9297      3333
#
#        accuracy                         0.9415      9999
#       macro avg     0.9422    0.9415    0.9417      9999
#    weighted avg     0.9422    0.9415    0.9417      9999
#
# ===
# climatefever-xlnet-base-cased.dev
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.4249    0.9892    0.5944      3333
#         REFUTES     0.9436    0.1104    0.1977      3333
#        SUPPORTS     0.7069    0.3921    0.5044      3333
#
#        accuracy                         0.4972      9999
#       macro avg     0.6918    0.4972    0.4322      9999
#    weighted avg     0.6918    0.4972    0.4322      9999
#
# ===
# climatefeverpure-bert-base-uncased.dev
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.6493    0.8650    0.7418      3333
#         REFUTES     0.9126    0.1848    0.3074      3333
#        SUPPORTS     0.5627    0.8245    0.6689      3333
#
#        accuracy                         0.6248      9999
#       macro avg     0.7082    0.6248    0.5727      9999
#    weighted avg     0.7082    0.6248    0.5727      9999
#
# ===
# fever-climatefeverpure-xlnet-base-cased.dev
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.9815    0.9568    0.9690      3333
#         REFUTES     0.9338    0.9058    0.9196      3333
#        SUPPORTS     0.9028    0.9526    0.9270      3333
#
#        accuracy                         0.9384      9999
#       macro avg     0.9394    0.9384    0.9385      9999
#    weighted avg     0.9394    0.9384    0.9385      9999
#
# ===
# fever-bert-base-uncased.dev
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.9821    0.9724    0.9772      3333
#         REFUTES     0.9403    0.9121    0.9260      3333
#        SUPPORTS     0.9123    0.9487    0.9301      3333
#
#        accuracy                         0.9444      9999
#       macro avg     0.9449    0.9444    0.9445      9999
#    weighted avg     0.9449    0.9444    0.9445      9999
#
# ===
# climatefever-bert-base-uncased.dev
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.5876    0.9781    0.7342      3333
#         REFUTES     0.9471    0.1236    0.2187      3333
#        SUPPORTS     0.6414    0.7729    0.7010      3333
#
#        accuracy                         0.6249      9999
#       macro avg     0.7254    0.6249    0.5513      9999
#    weighted avg     0.7254    0.6249    0.5513      9999
#
# ===
# fever-climatefever-xlnet-base-cased.dev
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.9823    0.9637    0.9729      3333
#         REFUTES     0.9372    0.9085    0.9226      3333
#        SUPPORTS     0.9079    0.9529    0.9299      3333
#
#        accuracy                         0.9417      9999
#       macro avg     0.9425    0.9417    0.9418      9999
#    weighted avg     0.9425    0.9417    0.9418      9999
#
# ===

# %%
for score in majority_agg_res["climatefeverpure"]["dev"]:
    print(score._score_name)
    print(score.classification_report)
    print("===")
# Out:
# fever-climatefeverpure-bert-base-uncased.dev
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.4824    0.4316    0.4556        95
#         REFUTES     0.3833    0.4510    0.4144        51
#        SUPPORTS     0.6842    0.6894    0.6868       132
#
#        accuracy                         0.5576       278
#       macro avg     0.5166    0.5240    0.5189       278
#    weighted avg     0.5600    0.5576    0.5578       278
#
# ===
# fever-climatefever-bert-base-uncased.dev
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.4933    0.7789    0.6041        95
#         REFUTES     0.5135    0.3725    0.4318        51
#        SUPPORTS     0.8022    0.5530    0.6547       132
#
#        accuracy                         0.5971       278
#       macro avg     0.6030    0.5682    0.5635       278
#    weighted avg     0.6437    0.5971    0.5965       278
#
# ===
# climatefeverpure-xlnet-base-cased.dev
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.5248    0.5579    0.5408        95
#         REFUTES     0.6875    0.4314    0.5301        51
#        SUPPORTS     0.6690    0.7348    0.7004       132
#
#        accuracy                         0.6187       278
#       macro avg     0.6271    0.5747    0.5904       278
#    weighted avg     0.6231    0.6187    0.6146       278
#
# ===
# fever-xlnet-base-cased.dev
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.3429    0.1263    0.1846        95
#         REFUTES     0.3448    0.5882    0.4348        51
#        SUPPORTS     0.5897    0.6970    0.6389       132
#
#        accuracy                         0.4820       278
#       macro avg     0.4258    0.4705    0.4194       278
#    weighted avg     0.4604    0.4820    0.4462       278
#
# ===
# climatefever-xlnet-base-cased.dev
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.4595    0.7158    0.5597        95
#         REFUTES     0.8500    0.3333    0.4789        51
#        SUPPORTS     0.6909    0.5758    0.6281       132
#
#        accuracy                         0.5791       278
#       macro avg     0.6668    0.5416    0.5555       278
#    weighted avg     0.6410    0.5791    0.5773       278
#
# ===
# climatefeverpure-bert-base-uncased.dev
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.4928    0.3579    0.4146        95
#         REFUTES     0.4634    0.3725    0.4130        51
#        SUPPORTS     0.6310    0.8030    0.7067       132
#
#        accuracy                         0.5719       278
#       macro avg     0.5290    0.5112    0.5114       278
#    weighted avg     0.5530    0.5719    0.5530       278
#
# ===
# fever-climatefeverpure-xlnet-base-cased.dev
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.4828    0.2947    0.3660        95
#         REFUTES     0.5600    0.5490    0.5545        51
#        SUPPORTS     0.6294    0.8106    0.7086       132
#
#        accuracy                         0.5863       278
#       macro avg     0.5574    0.5515    0.5430       278
#    weighted avg     0.5666    0.5863    0.5633       278
#
# ===
# fever-bert-base-uncased.dev
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.5217    0.1263    0.2034        95
#         REFUTES     0.2735    0.6275    0.3810        51
#        SUPPORTS     0.6739    0.7045    0.6889       132
#
#        accuracy                         0.4928       278
#       macro avg     0.4897    0.4861    0.4244       278
#    weighted avg     0.5485    0.4928    0.4665       278
#
# ===
# climatefever-bert-base-uncased.dev
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.4774    0.7789    0.5920        95
#         REFUTES     0.7727    0.3333    0.4658        51
#        SUPPORTS     0.7129    0.5455    0.6180       132
#
#        accuracy                         0.5863       278
#       macro avg     0.6543    0.5526    0.5586       278
#    weighted avg     0.6434    0.5863    0.5812       278
#
# ===
# fever-climatefever-xlnet-base-cased.dev
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.4255    0.8421    0.5654        95
#         REFUTES     0.6957    0.3137    0.4324        51
#        SUPPORTS     0.8060    0.4091    0.5427       132
#
#        accuracy                         0.5396       278
#       macro avg     0.6424    0.5216    0.5135       278
#    weighted avg     0.6557    0.5396    0.5302       278
#
# ===

# %%
for score in majority_agg_res["climatefever"]["dev"]:
    print(score._score_name)
    print(score.classification_report)
    print("===")
# Out:
# fever-climatefeverpure-bert-base-uncased.dev
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.5256    0.4316    0.4740        95
#         REFUTES     0.3750    0.4706    0.4174        51
#        SUPPORTS     0.6618    0.6818    0.6716       132
#
#        accuracy                         0.5576       278
#       macro avg     0.5208    0.5280    0.5210       278
#    weighted avg     0.5626    0.5576    0.5575       278
#
# ===
# fever-climatefever-bert-base-uncased.dev
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.5522    0.7789    0.6463        95
#         REFUTES     0.5385    0.4118    0.4667        51
#        SUPPORTS     0.8095    0.6439    0.7173       132
#
#        accuracy                         0.6475       278
#       macro avg     0.6334    0.6116    0.6101       278
#    weighted avg     0.6719    0.6475    0.6471       278
#
# ===
# climatefeverpure-xlnet-base-cased.dev
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.5699    0.5579    0.5638        95
#         REFUTES     0.6154    0.4706    0.5333        51
#        SUPPORTS     0.6644    0.7348    0.6978       132
#
#        accuracy                         0.6259       278
#       macro avg     0.6166    0.5878    0.5983       278
#    weighted avg     0.6231    0.6259    0.6219       278
#
# ===
# fever-xlnet-base-cased.dev
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.4000    0.1263    0.1920        95
#         REFUTES     0.3118    0.5686    0.4028        51
#        SUPPORTS     0.5742    0.6742    0.6202       132
#
#        accuracy                         0.4676       278
#       macro avg     0.4287    0.4564    0.4050       278
#    weighted avg     0.4665    0.4676    0.4340       278
#
# ===
# climatefever-xlnet-base-cased.dev
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.4857    0.7158    0.5787        95
#         REFUTES     0.8095    0.3333    0.4722        51
#        SUPPORTS     0.7094    0.6288    0.6667       132
#
#        accuracy                         0.6043       278
#       macro avg     0.6682    0.5593    0.5725       278
#    weighted avg     0.6513    0.6043    0.6009       278
#
# ===
# climatefeverpure-bert-base-uncased.dev
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.5152    0.3579    0.4224        95
#         REFUTES     0.4444    0.3922    0.4167        51
#        SUPPORTS     0.6228    0.7879    0.6957       132
#
#        accuracy                         0.5683       278
#       macro avg     0.5275    0.5126    0.5116       278
#    weighted avg     0.5533    0.5683    0.5511       278
#
# ===
# fever-climatefeverpure-xlnet-base-cased.dev
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.5600    0.2947    0.3862        95
#         REFUTES     0.5345    0.6078    0.5688        51
#        SUPPORTS     0.6235    0.8030    0.7020       132
#
#        accuracy                         0.5935       278
#       macro avg     0.5727    0.5685    0.5523       278
#    weighted avg     0.5855    0.5935    0.5696       278
#
# ===
# fever-bert-base-uncased.dev
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.5217    0.1263    0.2034        95
#         REFUTES     0.2742    0.6667    0.3886        51
#        SUPPORTS     0.6565    0.6515    0.6540       132
#
#        accuracy                         0.4748       278
#       macro avg     0.4841    0.4815    0.4153       278
#    weighted avg     0.5403    0.4748    0.4513       278
#
# ===
# climatefever-bert-base-uncased.dev
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.5481    0.7789    0.6435        95
#         REFUTES     0.7200    0.3529    0.4737        51
#        SUPPORTS     0.7373    0.6591    0.6960       132
#
#        accuracy                         0.6439       278
#       macro avg     0.6685    0.5970    0.6044       278
#    weighted avg     0.6695    0.6439    0.6373       278
#
# ===
# fever-climatefever-xlnet-base-cased.dev
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.4469    0.8421    0.5839        95
#         REFUTES     0.6800    0.3333    0.4474        51
#        SUPPORTS     0.8108    0.4545    0.5825       132
#
#        accuracy                         0.5647       278
#       macro avg     0.6459    0.5433    0.5379       278
#    weighted avg     0.6625    0.5647    0.5582       278
#
# ===

# %%
for score in majority_agg_res["scifact"]["all"]:
    print(score._score_name)
    print(score.classification_report)
    print("===")
# Out:
# fever-climatefever-xlnet-base-cased.all
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.7437    0.9976    0.8522       416
#         REFUTES     0.7661    0.4008    0.5263       237
#        SUPPORTS     0.8126    0.7610    0.7860       456
#
#        accuracy                         0.7728      1109
#       macro avg     0.7742    0.7198    0.7215      1109
#    weighted avg     0.7769    0.7728    0.7553      1109
#
# ===
# climatefeverpure-bert-base-uncased.all
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.8833    0.5457    0.6746       416
#         REFUTES     0.4615    0.1519    0.2286       237
#        SUPPORTS     0.5271    0.8947    0.6634       456
#
#        accuracy                         0.6050      1109
#       macro avg     0.6240    0.5308    0.5222      1109
#    weighted avg     0.6467    0.6050    0.5747      1109
#
# ===
# climatefever-xlnet-base-cased.all
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.6177    0.9399    0.7455       416
#         REFUTES     0.5312    0.0717    0.1264       237
#        SUPPORTS     0.7095    0.6908    0.7000       456
#
#        accuracy                         0.6519      1109
#       macro avg     0.6195    0.5675    0.5240      1109
#    weighted avg     0.6370    0.6519    0.5945      1109
#
# ===
# fever-bert-base-uncased.all
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.8653    0.9880    0.9226       416
#         REFUTES     0.6845    0.5401    0.6038       237
#        SUPPORTS     0.8076    0.7917    0.7996       456
#
#        accuracy                         0.8115      1109
#       macro avg     0.7858    0.7732    0.7753      1109
#    weighted avg     0.8029    0.8115    0.8039      1109
#
# ===
# fever-climatefeverpure-bert-base-uncased.all
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.8238    1.0000    0.9034       416
#         REFUTES     0.6686    0.4768    0.5567       237
#        SUPPORTS     0.8000    0.7632    0.7811       456
#
#        accuracy                         0.7908      1109
#       macro avg     0.7641    0.7467    0.7471      1109
#    weighted avg     0.7808    0.7908    0.7790      1109
#
# ===
# fever-climatefever-bert-base-uncased.all
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.7455    1.0000    0.8542       416
#         REFUTES     0.6733    0.4262    0.5220       237
#        SUPPORTS     0.8105    0.7127    0.7585       456
#
#        accuracy                         0.7592      1109
#       macro avg     0.7431    0.7130    0.7115      1109
#    weighted avg     0.7568    0.7592    0.7438      1109
#
# ===
# climatefever-bert-base-uncased.all
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.7996    0.9880    0.8839       416
#         REFUTES     0.5357    0.1266    0.2048       237
#        SUPPORTS     0.7087    0.8377    0.7678       456
#
#        accuracy                         0.7421      1109
#       macro avg     0.6813    0.6508    0.6188      1109
#    weighted avg     0.7058    0.7421    0.6910      1109
#
# ===
# fever-xlnet-base-cased.all
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.8023    0.9856    0.8846       416
#         REFUTES     0.7755    0.4810    0.5938       237
#        SUPPORTS     0.8137    0.8048    0.8093       456
#
#        accuracy                         0.8034      1109
#       macro avg     0.7972    0.7571    0.7625      1109
#    weighted avg     0.8013    0.8034    0.7915      1109
#
# ===
# fever-climatefeverpure-xlnet-base-cased.all
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.8111    0.9808    0.8879       416
#         REFUTES     0.7260    0.4473    0.5535       237
#        SUPPORTS     0.7957    0.8026    0.7991       456
#
#        accuracy                         0.7935      1109
#       macro avg     0.7776    0.7436    0.7469      1109
#    weighted avg     0.7866    0.7935    0.7799      1109
#
# ===
# climatefeverpure-xlnet-base-cased.all
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.7090    0.6851    0.6968       416
#         REFUTES     0.5730    0.2152    0.3129       237
#        SUPPORTS     0.5874    0.7961    0.6760       456
#
#        accuracy                         0.6303      1109
#       macro avg     0.6231    0.5654    0.5619      1109
#    weighted avg     0.6299    0.6303    0.6062      1109
#
# ===

# %% [markdown]
# ### Mean probability

# %%
meanproba_agg_res = {
    "fever": defaultdict(list), 
    "climatefeverpure": defaultdict(list), 
    "scifact": defaultdict(list),
    "climatefever": defaultdict(list)
}

for actual_dp in tqdm(actual_pls):
    dataset = actual_dp.parent.stem.split("-")[0]
    split = actual_dp.stem.split(".")[0]
    actual_data = read_data(actual_dp)
    if "climatefever" in dataset:
        score_obj = scorer.ClimateFEVERScorer
    else:
        score_obj = scorer.FEVERScorer
        
    for pp in pred_p.joinpath("sent", dataset).glob(f"*.{split}.jsonl"):
        preds = read_data(pp)
        sent_actual_data = read_data(data_sent_micro_p.joinpath("scifact.all.test.n5.jsonl" if dataset == "scifact" else f"{dataset}.{split}.n5.jsonl"))
        
        # aggregate
        df_agg = pd.DataFrame(sent_actual_data).merge(pd.DataFrame(preds), on="claim_id", how="left")
        df_agg = df_agg.groupby("claim_id", sort=False).agg({"predicted_proba": aggregate.agg_predict_proba})
        df_agg = df_agg.rename(columns={"predicted_proba": "predicted_label"})
        df_agg["predicted_label"] = df_agg["predicted_label"].map(constants.ID2LABEL)
        df_agg = df_agg.reset_index()
        df_agg = df_agg.to_dict("records")
        
        meanproba_agg_res[dataset][split].append(score_obj(actual_data=actual_data, prediction_data=df_agg, oracle_rte=False, oracle_ir=True, max_evidence=None, score_name=pp.stem))
# Out:
# 100%|██████████| 7/7 [00:22<00:00,  3.16s/it]

# %%
with result_p.joinpath("sent_macro_verdict_meanproba_metrics.pkl").open("wb") as fn:
    pkl.dump(meanproba_agg_res, fn)

# %%
for score in meanproba_agg_res["fever"]["dev"]:
    print(score._score_name)
    print(score.classification_report)
    print("===")
# Out:
# fever-climatefeverpure-bert-base-uncased.dev
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.9866    0.9928    0.9897      3333
#         REFUTES     0.9494    0.9061    0.9272      3333
#        SUPPORTS     0.9148    0.9508    0.9325      3333
#
#        accuracy                         0.9499      9999
#       macro avg     0.9503    0.9499    0.9498      9999
#    weighted avg     0.9503    0.9499    0.9498      9999
#
# ===
# fever-climatefever-bert-base-uncased.dev
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.9871    0.9877    0.9874      3333
#         REFUTES     0.9500    0.9058    0.9274      3333
#        SUPPORTS     0.9125    0.9544    0.9330      3333
#
#        accuracy                         0.9493      9999
#       macro avg     0.9499    0.9493    0.9492      9999
#    weighted avg     0.9499    0.9493    0.9492      9999
#
# ===
# climatefeverpure-xlnet-base-cased.dev
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.5256    0.9181    0.6685      3333
#         REFUTES     0.8976    0.1131    0.2009      3333
#        SUPPORTS     0.5789    0.6526    0.6135      3333
#
#        accuracy                         0.5613      9999
#       macro avg     0.6674    0.5613    0.4943      9999
#    weighted avg     0.6674    0.5613    0.4943      9999
#
# ===
# fever-xlnet-base-cased.dev
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.9907    0.9868    0.9887      3333
#         REFUTES     0.9442    0.9193    0.9316      3333
#        SUPPORTS     0.9228    0.9508    0.9366      3333
#
#        accuracy                         0.9523      9999
#       macro avg     0.9526    0.9523    0.9523      9999
#    weighted avg     0.9526    0.9523    0.9523      9999
#
# ===
# climatefever-xlnet-base-cased.dev
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.4119    0.9958    0.5827      3333
#         REFUTES     0.9537    0.0927    0.1690      3333
#        SUPPORTS     0.7081    0.3435    0.4626      3333
#
#        accuracy                         0.4773      9999
#       macro avg     0.6912    0.4773    0.4048      9999
#    weighted avg     0.6912    0.4773    0.4048      9999
#
# ===
# climatefeverpure-bert-base-uncased.dev
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.6252    0.9280    0.7471      3333
#         REFUTES     0.9246    0.1656    0.2809      3333
#        SUPPORTS     0.5854    0.7825    0.6697      3333
#
#        accuracy                         0.6254      9999
#       macro avg     0.7118    0.6254    0.5659      9999
#    weighted avg     0.7118    0.6254    0.5659      9999
#
# ===
# fever-climatefeverpure-xlnet-base-cased.dev
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.9891    0.9844    0.9868      3333
#         REFUTES     0.9477    0.9079    0.9274      3333
#        SUPPORTS     0.9114    0.9541    0.9323      3333
#
#        accuracy                         0.9488      9999
#       macro avg     0.9494    0.9488    0.9488      9999
#    weighted avg     0.9494    0.9488    0.9488      9999
#
# ===
# fever-bert-base-uncased.dev
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.9863    0.9901    0.9882      3333
#         REFUTES     0.9493    0.9109    0.9297      3333
#        SUPPORTS     0.9172    0.9508    0.9337      3333
#
#        accuracy                         0.9506      9999
#       macro avg     0.9509    0.9506    0.9505      9999
#    weighted avg     0.9509    0.9506    0.9505      9999
#
# ===
# climatefever-bert-base-uncased.dev
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.5531    0.9931    0.7105      3333
#         REFUTES     0.9619    0.0984    0.1786      3333
#        SUPPORTS     0.6538    0.7207    0.6856      3333
#
#        accuracy                         0.6041      9999
#       macro avg     0.7229    0.6041    0.5249      9999
#    weighted avg     0.7229    0.6041    0.5249      9999
#
# ===
# fever-climatefever-xlnet-base-cased.dev
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.9889    0.9850    0.9869      3333
#         REFUTES     0.9481    0.9100    0.9287      3333
#        SUPPORTS     0.9155    0.9559    0.9353      3333
#
#        accuracy                         0.9503      9999
#       macro avg     0.9508    0.9503    0.9503      9999
#    weighted avg     0.9508    0.9503    0.9503      9999
#
# ===

# %%
for score in meanproba_agg_res["climatefeverpure"]["dev"]:
    print(score._score_name)
    print(score.classification_report)
    print("===")
# Out:
# fever-climatefeverpure-bert-base-uncased.dev
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.5546    0.6947    0.6168        95
#         REFUTES     0.4773    0.4118    0.4421        51
#        SUPPORTS     0.7478    0.6515    0.6964       132
#
#        accuracy                         0.6223       278
#       macro avg     0.5932    0.5860    0.5851       278
#    weighted avg     0.6322    0.6223    0.6225       278
#
# ===
# fever-climatefever-bert-base-uncased.dev
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.4564    0.9368    0.6138        95
#         REFUTES     0.5417    0.2549    0.3467        51
#        SUPPORTS     0.9153    0.4091    0.5654       132
#
#        accuracy                         0.5612       278
#       macro avg     0.6378    0.5336    0.5086       278
#    weighted avg     0.6899    0.5612    0.5418       278
#
# ===
# climatefeverpure-xlnet-base-cased.dev
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.5378    0.6737    0.5981        95
#         REFUTES     0.7333    0.4314    0.5432        51
#        SUPPORTS     0.7054    0.6894    0.6973       132
#
#        accuracy                         0.6367       278
#       macro avg     0.6589    0.5982    0.6129       278
#    weighted avg     0.6533    0.6367    0.6352       278
#
# ===
# fever-xlnet-base-cased.dev
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.5493    0.4105    0.4699        95
#         REFUTES     0.3889    0.5490    0.4553        51
#        SUPPORTS     0.6519    0.6667    0.6592       132
#
#        accuracy                         0.5576       278
#       macro avg     0.5300    0.5421    0.5281       278
#    weighted avg     0.5686    0.5576    0.5571       278
#
# ===
# climatefever-xlnet-base-cased.dev
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.4451    0.8526    0.5848        95
#         REFUTES     0.8000    0.2353    0.3636        51
#        SUPPORTS     0.7531    0.4621    0.5728       132
#
#        accuracy                         0.5540       278
#       macro avg     0.6660    0.5167    0.5071       278
#    weighted avg     0.6564    0.5540    0.5385       278
#
# ===
# climatefeverpure-bert-base-uncased.dev
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.5941    0.6316    0.6122        95
#         REFUTES     0.5625    0.3529    0.4337        51
#        SUPPORTS     0.7034    0.7727    0.7365       132
#
#        accuracy                         0.6475       278
#       macro avg     0.6200    0.5857    0.5941       278
#    weighted avg     0.6402    0.6475    0.6385       278
#
# ===
# fever-climatefeverpure-xlnet-base-cased.dev
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.6087    0.5895    0.5989        95
#         REFUTES     0.7436    0.5686    0.6444        51
#        SUPPORTS     0.6871    0.7652    0.7240       132
#
#        accuracy                         0.6691       278
#       macro avg     0.6798    0.6411    0.6558       278
#    weighted avg     0.6707    0.6691    0.6667       278
#
# ===
# fever-bert-base-uncased.dev
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.6957    0.1684    0.2712        95
#         REFUTES     0.2857    0.6667    0.4000        51
#        SUPPORTS     0.6765    0.6970    0.6866       132
#
#        accuracy                         0.5108       278
#       macro avg     0.5526    0.5107    0.4526       278
#    weighted avg     0.6113    0.5108    0.4920       278
#
# ===
# climatefever-bert-base-uncased.dev
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.4631    0.9895    0.6309        95
#         REFUTES     0.7778    0.2745    0.4058        51
#        SUPPORTS     0.8947    0.3864    0.5397       132
#
#        accuracy                         0.5719       278
#       macro avg     0.7119    0.5501    0.5255       278
#    weighted avg     0.7258    0.5719    0.5463       278
#
# ===
# fever-climatefever-xlnet-base-cased.dev
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.4174    0.9579    0.5815        95
#         REFUTES     0.8571    0.2353    0.3692        51
#        SUPPORTS     0.8696    0.3030    0.4494       132
#
#        accuracy                         0.5144       278
#       macro avg     0.7147    0.4987    0.4667       278
#    weighted avg     0.7128    0.5144    0.4798       278
#
# ===

# %%
for score in meanproba_agg_res["climatefever"]["dev"]:
    print(score._score_name)
    print(score.classification_report)
    print("===")
# Out:
# fever-climatefeverpure-bert-base-uncased.dev
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.5280    0.6947    0.6000        95
#         REFUTES     0.4667    0.4118    0.4375        51
#        SUPPORTS     0.7407    0.6061    0.6667       132
#
#        accuracy                         0.6007       278
#       macro avg     0.5785    0.5709    0.5681       278
#    weighted avg     0.6178    0.6007    0.6018       278
#
# ===
# fever-climatefever-bert-base-uncased.dev
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.4101    0.9368    0.5705        95
#         REFUTES     0.5000    0.1569    0.2388        51
#        SUPPORTS     0.9111    0.3106    0.4633       132
#
#        accuracy                         0.4964       278
#       macro avg     0.6071    0.4681    0.4242       278
#    weighted avg     0.6645    0.4964    0.4587       278
#
# ===
# climatefeverpure-xlnet-base-cased.dev
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.5333    0.6737    0.5953        95
#         REFUTES     0.6571    0.4510    0.5349        51
#        SUPPORTS     0.6911    0.6439    0.6667       132
#
#        accuracy                         0.6187       278
#       macro avg     0.6272    0.5895    0.5990       278
#    weighted avg     0.6309    0.6187    0.6181       278
#
# ===
# fever-xlnet-base-cased.dev
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.5493    0.4105    0.4699        95
#         REFUTES     0.3375    0.5294    0.4122        51
#        SUPPORTS     0.6299    0.6061    0.6178       132
#
#        accuracy                         0.5252       278
#       macro avg     0.5056    0.5153    0.5000       278
#    weighted avg     0.5487    0.5252    0.5295       278
#
# ===
# climatefever-xlnet-base-cased.dev
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.4263    0.8526    0.5684        95
#         REFUTES     0.8000    0.2353    0.3636        51
#        SUPPORTS     0.7671    0.4242    0.5463       132
#
#        accuracy                         0.5360       278
#       macro avg     0.6645    0.5041    0.4928       278
#    weighted avg     0.6567    0.5360    0.5204       278
#
# ===
# climatefeverpure-bert-base-uncased.dev
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.5769    0.6316    0.6030        95
#         REFUTES     0.5758    0.3725    0.4524        51
#        SUPPORTS     0.6879    0.7348    0.7106       132
#
#        accuracy                         0.6331       278
#       macro avg     0.6135    0.5797    0.5887       278
#    weighted avg     0.6294    0.6331    0.6265       278
#
# ===
# fever-climatefeverpure-xlnet-base-cased.dev
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.5385    0.5895    0.5628        95
#         REFUTES     0.6667    0.5490    0.6022        51
#        SUPPORTS     0.6667    0.6667    0.6667       132
#
#        accuracy                         0.6187       278
#       macro avg     0.6239    0.6017    0.6105       278
#    weighted avg     0.6229    0.6187    0.6193       278
#
# ===
# fever-bert-base-uncased.dev
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.6154    0.1684    0.2645        95
#         REFUTES     0.2623    0.6275    0.3699        51
#        SUPPORTS     0.6462    0.6364    0.6412       132
#
#        accuracy                         0.4748       278
#       macro avg     0.5079    0.4774    0.4252       278
#    weighted avg     0.5652    0.4748    0.4627       278
#
# ===
# climatefever-bert-base-uncased.dev
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.4105    0.9895    0.5802        95
#         REFUTES     0.8333    0.1961    0.3175        51
#        SUPPORTS     0.9459    0.2652    0.4142       132
#
#        accuracy                         0.5000       278
#       macro avg     0.7299    0.4836    0.4373       278
#    weighted avg     0.7423    0.5000    0.4532       278
#
# ===
# fever-climatefever-xlnet-base-cased.dev
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.3792    0.9579    0.5433        95
#         REFUTES     0.7500    0.1765    0.2857        51
#        SUPPORTS     0.8077    0.1591    0.2658       132
#
#        accuracy                         0.4353       278
#       macro avg     0.6456    0.4312    0.3649       278
#    weighted avg     0.6507    0.4353    0.3643       278
#
# ===

# %%
for score in meanproba_agg_res["scifact"]["all"]:
    print(score._score_name)
    print(score.classification_report)
    print("===")
# Out:
# fever-climatefever-xlnet-base-cased.all
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.6770    0.9976    0.8066       416
#         REFUTES     0.7615    0.3502    0.4798       237
#        SUPPORTS     0.8088    0.6864    0.7426       456
#
#        accuracy                         0.7313      1109
#       macro avg     0.7491    0.6781    0.6763      1109
#    weighted avg     0.7492    0.7313    0.7104      1109
#
# ===
# climatefeverpure-bert-base-uncased.all
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.8889    0.6538    0.7535       416
#         REFUTES     0.4857    0.1435    0.2215       237
#        SUPPORTS     0.5539    0.8904    0.6829       456
#
#        accuracy                         0.6420      1109
#       macro avg     0.6428    0.5626    0.5526      1109
#    weighted avg     0.6650    0.6420    0.6108      1109
#
# ===
# climatefever-xlnet-base-cased.all
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.5682    0.9712    0.7169       416
#         REFUTES     0.6190    0.0549    0.1008       237
#        SUPPORTS     0.7241    0.5987    0.6555       456
#
#        accuracy                         0.6222      1109
#       macro avg     0.6371    0.5416    0.4911      1109
#    weighted avg     0.6432    0.6222    0.5600      1109
#
# ===
# fever-bert-base-uncased.all
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.8814    1.0000    0.9369       416
#         REFUTES     0.6649    0.5190    0.5829       237
#        SUPPORTS     0.8075    0.8004    0.8040       456
#
#        accuracy                         0.8151      1109
#       macro avg     0.7846    0.7731    0.7746      1109
#    weighted avg     0.8047    0.8151    0.8066      1109
#
# ===
# fever-climatefeverpure-bert-base-uncased.all
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.7894    1.0000    0.8823       416
#         REFUTES     0.6343    0.4684    0.5388       237
#        SUPPORTS     0.8084    0.7215    0.7625       456
#
#        accuracy                         0.7719      1109
#       macro avg     0.7440    0.7299    0.7279      1109
#    weighted avg     0.7640    0.7719    0.7596      1109
#
# ===
# fever-climatefever-bert-base-uncased.all
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.6831    1.0000    0.8117       416
#         REFUTES     0.6479    0.3882    0.4855       237
#        SUPPORTS     0.8324    0.6535    0.7322       456
#
#        accuracy                         0.7268      1109
#       macro avg     0.7211    0.6806    0.6765      1109
#    weighted avg     0.7370    0.7268    0.7093      1109
#
# ===
# climatefever-bert-base-uncased.all
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.7205    0.9976    0.8367       416
#         REFUTES     0.5217    0.1013    0.1696       237
#        SUPPORTS     0.7207    0.7697    0.7444       456
#
#        accuracy                         0.7124      1109
#       macro avg     0.6543    0.6229    0.5836      1109
#    weighted avg     0.6781    0.7124    0.6562      1109
#
# ===
# fever-xlnet-base-cased.all
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.7720    0.9928    0.8686       416
#         REFUTES     0.7762    0.4684    0.5842       237
#        SUPPORTS     0.8213    0.7763    0.7982       456
#
#        accuracy                         0.7917      1109
#       macro avg     0.7898    0.7458    0.7503      1109
#    weighted avg     0.7932    0.7917    0.7789      1109
#
# ===
# fever-climatefeverpure-xlnet-base-cased.all
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.7662    0.9928    0.8649       416
#         REFUTES     0.7206    0.4135    0.5255       237
#        SUPPORTS     0.7834    0.7456    0.7640       456
#
#        accuracy                         0.7674      1109
#       macro avg     0.7567    0.7173    0.7181      1109
#    weighted avg     0.7635    0.7674    0.7509      1109
#
# ===
# climatefeverpure-xlnet-base-cased.all
#                  precision    recall  f1-score   support
#
# NOT ENOUGH INFO     0.6645    0.7380    0.6993       416
#         REFUTES     0.6087    0.1772    0.2745       237
#        SUPPORTS     0.6073    0.7697    0.6789       456
#
#        accuracy                         0.6312      1109
#       macro avg     0.6268    0.5616    0.5509      1109
#    weighted avg     0.6290    0.6312    0.6001      1109
#
# ===
